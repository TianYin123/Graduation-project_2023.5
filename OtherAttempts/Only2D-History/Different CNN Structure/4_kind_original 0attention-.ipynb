# %%
import numpy as np
import torch
import os
import random
from torch.utils.data import Dataset
import torch.nn.functional as F
import torch.nn as nn
import nibabel as nib

import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from torch.utils.data import ConcatDataset
import torchvision.models as models
import copy

# %%
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
 
        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)
 
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, x): 
        # the shape of x is (b c h w)
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        attn = self.sigmoid(out) # (b c)
        x = x * attn[:, :, None, None]
        return x

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
 
        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1
 
        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, x): 
        # the shape of x is (b c h w)
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        attn = torch.cat([avg_out, max_out], dim=1)
        attn = self.conv1(attn) # b 1 h w
        attn = self.sigmoid(attn)
        attn = torch.squeeze(attn, dim=1) # b h w
        x = attn[:, None, :, :] * x
        return x

# %%
random.seed(3407)
rmb_label = {"ASD": 0, "TD": 1}      # 设置标签

class MultiModalDataset(Dataset):
    def __init__(self, data_dirho, data_diraal,data_direz , data_dircsv, transform=None):
        """ 
        ABIDE_db的Dataset
        :param data_dir: str, 数据集所在路径
        :param transform: torch.transform，数据预处理
        """
        self.label_name = {"ASD": 0, "TD": 1}
        self.data_infocsv = self.get_csv_info(data_dircsv)  # data_info存储所有txt路径和标签，在DataLoader中通过index读取样本
        self.data_infoez = self.get_1D_info(data_direz)  # data_info存储所有txt路径和标签，在DataLoader中通过index读取样本
        self.data_infoho = self.get_1D_info(data_dirho)
        self.data_infoaal = self.get_1D_info(data_diraal)

        self.transform = transform
        

        
    def __getitem__(self, index):
        path_csv, label_csv = self.data_infocsv[index]
        txt_data = np.loadtxt(path_csv, delimiter=',')
        label = label_csv
        csv = torch.from_numpy(txt_data).float().unsqueeze(0)
        ez = self.process_data(method='ez',index=index,labels=label_csv)
        ho = self.process_data(method='ho',index=index,labels=label_csv)
        aal = self.process_data(method='aal',index=index,labels=label_csv)

        if self.transform is not None:
            txt = 1   # 在这里做transform，转为tensor等等

        return ho,aal,ez,csv,label

    def __len__(self):
        return len(self.data_infocsv)

    @staticmethod
    def get_csv_info(data_dir):
        data_infocsv = list()
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            for sub_dir in dirs:
                txt_names = os.listdir(os.path.join(root, sub_dir))
                txt_names = list(filter(lambda x: x.endswith('.csv'), txt_names))

                # 遍历txt
                for i in range(len(txt_names)):
                    txt_name = txt_names[i]
                    path_txt = os.path.join(root, sub_dir, txt_name)
                    label = rmb_label[sub_dir]
                    data_infocsv.append((path_txt, int(label)))
                    data_infocsv = sorted(data_infocsv)

        return data_infocsv
    
    def get_1D_info(self,data_dir):
        data_infonii = list()
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            for sub_dir in dirs:
                txt_names = os.listdir(os.path.join(root, sub_dir))
                txt_names = list(filter(lambda x: x.endswith('.1D'), txt_names))

                # 遍历txt
                for i in range(len(txt_names)):
                    txt_name = txt_names[i]
                    path_txt = os.path.join(root, sub_dir, txt_name)
                    label = rmb_label[sub_dir]
                    data_infonii.append((path_txt, int(label)))
                    data_infonii = sorted(data_infonii)
        return data_infonii
    
    def process_data(self,method,index,labels):
        if method == 'ez':
            path, label = self.data_infoez[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            cor = torch.from_numpy(cor).float().unsqueeze(0)
        if method == 'ho':
            path, label = self.data_infoho[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            file1 = np.pad(cor, ((0, 5), (0, 5)), mode='constant')
            cor = torch.from_numpy(file1).float().unsqueeze(0)
        if method == 'aal':
            path, label = self.data_infoaal[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            cor = torch.from_numpy(cor).float().unsqueeze(0)
        if labels != label:
            print('Error: label not match!')
            print('the error 1D:{}',path)
        
        
        return cor

# %%
class SimpleCNN_aal(nn.Module):
    def __init__(self):
        super(SimpleCNN_aal, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)
    
        # self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        # x = self.channel_attention2(x)
        # x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
csv_split_dir = os.path.join('easy/not modify/csv_split')  
csv_train_dir = os.path.join(csv_split_dir, "train")
csv_valid_dir = os.path.join(csv_split_dir, "valid")
csv_test_dir  = os.path.join(csv_split_dir, "test") 
aal_split_dir = os.path.join('easy/not modify/aal_split')  
aal_train_dir = os.path.join(aal_split_dir, "train")
aal_valid_dir = os.path.join(aal_split_dir, "valid")
aal_test_dir  = os.path.join(aal_split_dir, "test") 
ho_split_dir = os.path.join('easy/not modify/rho_split')  
ho_train_dir = os.path.join(ho_split_dir, "train")
ho_valid_dir = os.path.join(ho_split_dir, "valid")
ho_test_dir  = os.path.join(ho_split_dir, "test") 
ez_split_dir = os.path.join('easy/not modify/ez_split')  
ez_train_dir = os.path.join(ez_split_dir, "train")
ez_valid_dir = os.path.join(ez_split_dir, "valid")
ez_test_dir  = os.path.join(ez_split_dir, "test")

# %% [markdown]
# # aal

# %%
#aal
# 定义超参数

input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 70
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_aal()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
# 初始化
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None

# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(aal)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(aal)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_aal_notmodify_0attention.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_aal_notmodify_0attention.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/70], Train Loss: 0.9185, Train Accuracy: 0.4924, Validation Loss: 0.7390, Validation Accuracy: 0.4647
# Epoch [2/70], Train Loss: 0.7095, Train Accuracy: 0.4772, Validation Loss: 0.6907, Validation Accuracy: 0.5353
# Epoch [3/70], Train Loss: 0.6923, Train Accuracy: 0.5346, Validation Loss: 0.6918, Validation Accuracy: 0.5353
# Epoch [4/70], Train Loss: 0.6899, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [5/70], Train Loss: 0.6903, Train Accuracy: 0.5346, Validation Loss: 0.6908, Validation Accuracy: 0.5353
# Epoch [6/70], Train Loss: 0.6892, Train Accuracy: 0.5346, Validation Loss: 0.6905, Validation Accuracy: 0.5353
# Epoch [7/70], Train Loss: 0.6883, Train Accuracy: 0.5346, Validation Loss: 0.6901, Validation Accuracy: 0.5353
# Epoch [8/70], Train Loss: 0.6865, Train Accuracy: 0.5346, Validation Loss: 0.6896, Validation Accuracy: 0.5353
# Epoch [9/70], Train Loss: 0.6843, Train Accuracy: 0.5346, Validation Loss: 0.6894, Validation Accuracy: 0.5353
# Epoch [10/70], Train Loss: 0.6799, Train Accuracy: 0.5346, Validation Loss: 0.6879, Validation Accuracy: 0.5353
# Epoch [11/70], Train Loss: 0.6703, Train Accuracy: 0.6391, Validation Loss: 0.6855, Validation Accuracy: 0.5529
# Epoch [12/70], Train Loss: 0.6573, Train Accuracy: 0.6105, Validation Loss: 0.6824, Validation Accuracy: 0.5412
# Epoch [13/70], Train Loss: 0.6355, Train Accuracy: 0.6560, Validation Loss: 0.6769, Validation Accuracy: 0.5765
# Epoch [14/70], Train Loss: 0.6055, Train Accuracy: 0.7218, Validation Loss: 0.6706, Validation Accuracy: 0.5941
# Epoch [15/70], Train Loss: 0.5851, Train Accuracy: 0.7336, Validation Loss: 0.6701, Validation Accuracy: 0.5765
# Epoch [16/70], Train Loss: 0.5468, Train Accuracy: 0.7454, Validation Loss: 0.6687, Validation Accuracy: 0.5824
# Epoch [17/70], Train Loss: 0.5105, Train Accuracy: 0.7926, Validation Loss: 0.7113, Validation Accuracy: 0.5588
# Epoch [18/70], Train Loss: 0.4912, Train Accuracy: 0.7858, Validation Loss: 0.7052, Validation Accuracy: 0.5765
# Epoch [19/70], Train Loss: 0.5018, Train Accuracy: 0.7403, Validation Loss: 0.7140, Validation Accuracy: 0.5765
# Epoch [20/70], Train Loss: 0.4668, Train Accuracy: 0.7993, Validation Loss: 0.6677, Validation Accuracy: 0.6235
# Epoch [21/70], Train Loss: 0.4201, Train Accuracy: 0.8381, Validation Loss: 0.6504, Validation Accuracy: 0.6059
# Epoch [22/70], Train Loss: 0.3833, Train Accuracy: 0.8718, Validation Loss: 0.6565, Validation Accuracy: 0.6176
# Epoch [23/70], Train Loss: 0.3430, Train Accuracy: 0.8887, Validation Loss: 0.6815, Validation Accuracy: 0.6294
# Epoch [24/70], Train Loss: 0.3224, Train Accuracy: 0.8853, Validation Loss: 0.6953, Validation Accuracy: 0.6118
# Epoch [25/70], Train Loss: 0.2956, Train Accuracy: 0.9056, Validation Loss: 0.7249, Validation Accuracy: 0.6118
# Epoch [26/70], Train Loss: 0.2659, Train Accuracy: 0.9123, Validation Loss: 0.7459, Validation Accuracy: 0.6176
# Epoch [27/70], Train Loss: 0.2283, Train Accuracy: 0.9342, Validation Loss: 0.6985, Validation Accuracy: 0.6353
# Epoch [28/70], Train Loss: 0.1940, Train Accuracy: 0.9612, Validation Loss: 0.7078, Validation Accuracy: 0.6471
# Epoch [29/70], Train Loss: 0.1579, Train Accuracy: 0.9899, Validation Loss: 0.7251, Validation Accuracy: 0.6412
# Epoch [30/70], Train Loss: 0.1262, Train Accuracy: 0.9933, Validation Loss: 0.7642, Validation Accuracy: 0.6294
# Epoch [31/70], Train Loss: 0.1032, Train Accuracy: 0.9949, Validation Loss: 0.7922, Validation Accuracy: 0.6118
# Epoch [32/70], Train Loss: 0.0826, Train Accuracy: 0.9966, Validation Loss: 0.8348, Validation Accuracy: 0.6412
# Epoch [33/70], Train Loss: 0.0648, Train Accuracy: 0.9983, Validation Loss: 0.8650, Validation Accuracy: 0.6235
# Epoch [34/70], Train Loss: 0.0502, Train Accuracy: 1.0000, Validation Loss: 0.8851, Validation Accuracy: 0.6353
# Epoch [35/70], Train Loss: 0.0401, Train Accuracy: 1.0000, Validation Loss: 0.9307, Validation Accuracy: 0.6294
# Epoch [36/70], Train Loss: 0.0316, Train Accuracy: 1.0000, Validation Loss: 0.9359, Validation Accuracy: 0.6059
# Epoch [37/70], Train Loss: 0.0238, Train Accuracy: 1.0000, Validation Loss: 0.9788, Validation Accuracy: 0.6294
# Epoch [38/70], Train Loss: 0.0200, Train Accuracy: 1.0000, Validation Loss: 1.0015, Validation Accuracy: 0.6235
# Early stopping triggered.
# Bestloss
# Accuracy: 0.6047
# Sensitivity: 0.6087
# Specificity: 0.6000
# Positive Predictive Value: 0.6364
# Negative Predictive Value: 0.5714
#
# Bestacc
# Accuracy: 0.6047
# Sensitivity: 0.6087
# Specificity: 0.6000
# Positive Predictive Value: 0.6364
# Negative Predictive Value: 0.5714

# %% [markdown]
# # Ho

# %%
class SimpleCNN_ho(nn.Module):
    def __init__(self):
        super(SimpleCNN_ho, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
#aal
# 定义超参数

input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_ho()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
# 初始化
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None

# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(ho)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(ho)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_ho_notmodify_0attention.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_ho_notmodify_0attention.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 0.9117, Train Accuracy: 0.5126, Validation Loss: 0.8364, Validation Accuracy: 0.4647
# Epoch [2/50], Train Loss: 0.7496, Train Accuracy: 0.4654, Validation Loss: 0.6915, Validation Accuracy: 0.5353
# Epoch [3/50], Train Loss: 0.6913, Train Accuracy: 0.5346, Validation Loss: 0.6907, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6897, Train Accuracy: 0.5346, Validation Loss: 0.6907, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6894, Train Accuracy: 0.5346, Validation Loss: 0.6900, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6888, Train Accuracy: 0.5346, Validation Loss: 0.6908, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6859, Train Accuracy: 0.5346, Validation Loss: 0.6896, Validation Accuracy: 0.5353
# Epoch [8/50], Train Loss: 0.6841, Train Accuracy: 0.5346, Validation Loss: 0.6889, Validation Accuracy: 0.5353
# Epoch [9/50], Train Loss: 0.6830, Train Accuracy: 0.5346, Validation Loss: 0.6893, Validation Accuracy: 0.5353
# Epoch [10/50], Train Loss: 0.6762, Train Accuracy: 0.5346, Validation Loss: 0.6871, Validation Accuracy: 0.5353
# Epoch [11/50], Train Loss: 0.6731, Train Accuracy: 0.5649, Validation Loss: 0.6867, Validation Accuracy: 0.5353
# Epoch [12/50], Train Loss: 0.6675, Train Accuracy: 0.5346, Validation Loss: 0.6875, Validation Accuracy: 0.5353
# Epoch [13/50], Train Loss: 0.6611, Train Accuracy: 0.6678, Validation Loss: 0.6833, Validation Accuracy: 0.5412
# Epoch [14/50], Train Loss: 0.6492, Train Accuracy: 0.5683, Validation Loss: 0.6869, Validation Accuracy: 0.5471
# Epoch [15/50], Train Loss: 0.6385, Train Accuracy: 0.6644, Validation Loss: 0.6834, Validation Accuracy: 0.5471
# Epoch [16/50], Train Loss: 0.6318, Train Accuracy: 0.6138, Validation Loss: 0.6786, Validation Accuracy: 0.5706
# Epoch [17/50], Train Loss: 0.6185, Train Accuracy: 0.7167, Validation Loss: 0.7053, Validation Accuracy: 0.5471
# Epoch [18/50], Train Loss: 0.6097, Train Accuracy: 0.6948, Validation Loss: 0.6816, Validation Accuracy: 0.5941
# Epoch [19/50], Train Loss: 0.5955, Train Accuracy: 0.6897, Validation Loss: 0.6881, Validation Accuracy: 0.5647
# Epoch [20/50], Train Loss: 0.5904, Train Accuracy: 0.7352, Validation Loss: 0.7077, Validation Accuracy: 0.5647
# Epoch [21/50], Train Loss: 0.5734, Train Accuracy: 0.7538, Validation Loss: 0.6987, Validation Accuracy: 0.5588
# Epoch [22/50], Train Loss: 0.5571, Train Accuracy: 0.7487, Validation Loss: 0.6993, Validation Accuracy: 0.5706
# Epoch [23/50], Train Loss: 0.5414, Train Accuracy: 0.7555, Validation Loss: 0.6730, Validation Accuracy: 0.5471
# Epoch [24/50], Train Loss: 0.5312, Train Accuracy: 0.7825, Validation Loss: 0.6840, Validation Accuracy: 0.5765
# Epoch [25/50], Train Loss: 0.5123, Train Accuracy: 0.7875, Validation Loss: 0.6617, Validation Accuracy: 0.6059
# Epoch [26/50], Train Loss: 0.5171, Train Accuracy: 0.7791, Validation Loss: 0.6597, Validation Accuracy: 0.6059
# Epoch [27/50], Train Loss: 0.4941, Train Accuracy: 0.7960, Validation Loss: 0.6785, Validation Accuracy: 0.5941
# Epoch [28/50], Train Loss: 0.4776, Train Accuracy: 0.8752, Validation Loss: 0.7463, Validation Accuracy: 0.5941
# Epoch [29/50], Train Loss: 0.4583, Train Accuracy: 0.8550, Validation Loss: 0.6969, Validation Accuracy: 0.5941
# Epoch [30/50], Train Loss: 0.4299, Train Accuracy: 0.8668, Validation Loss: 0.7059, Validation Accuracy: 0.5941
# Epoch [31/50], Train Loss: 0.4074, Train Accuracy: 0.9005, Validation Loss: 0.6824, Validation Accuracy: 0.6235
# Epoch [32/50], Train Loss: 0.3981, Train Accuracy: 0.8988, Validation Loss: 0.7551, Validation Accuracy: 0.6059
# Epoch [33/50], Train Loss: 0.3777, Train Accuracy: 0.9157, Validation Loss: 0.7029, Validation Accuracy: 0.6235
# Epoch [34/50], Train Loss: 0.3572, Train Accuracy: 0.9342, Validation Loss: 0.7307, Validation Accuracy: 0.6235
# Epoch [35/50], Train Loss: 0.3410, Train Accuracy: 0.9528, Validation Loss: 0.8081, Validation Accuracy: 0.6176
# Epoch [36/50], Train Loss: 0.3332, Train Accuracy: 0.9562, Validation Loss: 0.8318, Validation Accuracy: 0.6176
# Epoch [37/50], Train Loss: 0.3220, Train Accuracy: 0.9629, Validation Loss: 0.7490, Validation Accuracy: 0.6412
# Epoch [38/50], Train Loss: 0.3120, Train Accuracy: 0.9781, Validation Loss: 0.7882, Validation Accuracy: 0.6353
# Epoch [39/50], Train Loss: 0.3031, Train Accuracy: 0.9848, Validation Loss: 0.8315, Validation Accuracy: 0.6235
# Epoch [40/50], Train Loss: 0.3045, Train Accuracy: 0.9781, Validation Loss: 0.8827, Validation Accuracy: 0.6176
# Epoch [41/50], Train Loss: 0.2976, Train Accuracy: 0.9747, Validation Loss: 0.7990, Validation Accuracy: 0.6353
# Epoch [42/50], Train Loss: 0.2939, Train Accuracy: 0.9899, Validation Loss: 0.6929, Validation Accuracy: 0.6294
# Epoch [43/50], Train Loss: 0.2850, Train Accuracy: 0.9865, Validation Loss: 0.8048, Validation Accuracy: 0.6412
# Epoch [44/50], Train Loss: 0.2742, Train Accuracy: 0.9916, Validation Loss: 0.8243, Validation Accuracy: 0.6412
# Epoch [45/50], Train Loss: 0.2666, Train Accuracy: 0.9933, Validation Loss: 0.7300, Validation Accuracy: 0.6176
# Epoch [46/50], Train Loss: 0.2647, Train Accuracy: 0.9916, Validation Loss: 0.8233, Validation Accuracy: 0.6529
# Epoch [47/50], Train Loss: 0.2592, Train Accuracy: 0.9933, Validation Loss: 0.9149, Validation Accuracy: 0.6353
# Epoch [48/50], Train Loss: 0.2489, Train Accuracy: 0.9949, Validation Loss: 0.8343, Validation Accuracy: 0.6471
# Epoch [49/50], Train Loss: 0.2435, Train Accuracy: 0.9949, Validation Loss: 0.9094, Validation Accuracy: 0.6412
# Epoch [50/50], Train Loss: 0.2432, Train Accuracy: 0.9966, Validation Loss: 0.7801, Validation Accuracy: 0.6353
# Bestloss
# Accuracy: 0.5930
# Sensitivity: 0.8478
# Specificity: 0.3000
# Positive Predictive Value: 0.5821
# Negative Predictive Value: 0.6316
#
# Bestacc
# Accuracy: 0.4884
# Sensitivity: 0.7826
# Specificity: 0.1500
# Positive Predictive Value: 0.5143
# Negative Predictive Value: 0.3750

# %% [markdown]
# # ez

# %%
class SimpleCNN_ez(nn.Module):
    def __init__(self):
        super(SimpleCNN_ez, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# 定义超参数
input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_ez()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None
# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(ez)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(ez)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_ez_notmodify_0attention.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_ez_notmodify_0attention.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 0.8127, Train Accuracy: 0.4975, Validation Loss: 0.7057, Validation Accuracy: 0.5353
# Epoch [2/50], Train Loss: 0.7099, Train Accuracy: 0.5346, Validation Loss: 0.6953, Validation Accuracy: 0.5353
# Epoch [3/50], Train Loss: 0.6899, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6890, Train Accuracy: 0.5346, Validation Loss: 0.6911, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6893, Train Accuracy: 0.5346, Validation Loss: 0.6909, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6886, Train Accuracy: 0.5346, Validation Loss: 0.6905, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6868, Train Accuracy: 0.5346, Validation Loss: 0.6895, Validation Accuracy: 0.5353
# Epoch [8/50], Train Loss: 0.6821, Train Accuracy: 0.5346, Validation Loss: 0.6877, Validation Accuracy: 0.5353
# Epoch [9/50], Train Loss: 0.6734, Train Accuracy: 0.5363, Validation Loss: 0.6856, Validation Accuracy: 0.5118
# Epoch [10/50], Train Loss: 0.6616, Train Accuracy: 0.6880, Validation Loss: 0.6839, Validation Accuracy: 0.5647
# Epoch [11/50], Train Loss: 0.6452, Train Accuracy: 0.6088, Validation Loss: 0.6857, Validation Accuracy: 0.5647
# Epoch [12/50], Train Loss: 0.6361, Train Accuracy: 0.6712, Validation Loss: 0.6840, Validation Accuracy: 0.5412
# Epoch [13/50], Train Loss: 0.6100, Train Accuracy: 0.7116, Validation Loss: 0.6831, Validation Accuracy: 0.5588
# Epoch [14/50], Train Loss: 0.5879, Train Accuracy: 0.7234, Validation Loss: 0.6859, Validation Accuracy: 0.5412
# Epoch [15/50], Train Loss: 0.5658, Train Accuracy: 0.7302, Validation Loss: 0.7703, Validation Accuracy: 0.5588
# Epoch [16/50], Train Loss: 0.5873, Train Accuracy: 0.6661, Validation Loss: 0.7253, Validation Accuracy: 0.5353
# Epoch [17/50], Train Loss: 0.5424, Train Accuracy: 0.7386, Validation Loss: 0.7741, Validation Accuracy: 0.5353
# Epoch [18/50], Train Loss: 0.5467, Train Accuracy: 0.7218, Validation Loss: 0.7373, Validation Accuracy: 0.5588
# Epoch [19/50], Train Loss: 0.5179, Train Accuracy: 0.7690, Validation Loss: 0.7060, Validation Accuracy: 0.5824
# Epoch [20/50], Train Loss: 0.4851, Train Accuracy: 0.8044, Validation Loss: 0.6991, Validation Accuracy: 0.5412
# Epoch [21/50], Train Loss: 0.4478, Train Accuracy: 0.8246, Validation Loss: 0.7014, Validation Accuracy: 0.5529
# Epoch [22/50], Train Loss: 0.4157, Train Accuracy: 0.8331, Validation Loss: 0.7280, Validation Accuracy: 0.5471
# Epoch [23/50], Train Loss: 0.3680, Train Accuracy: 0.8499, Validation Loss: 0.7622, Validation Accuracy: 0.6176
# Epoch [24/50], Train Loss: 0.3214, Train Accuracy: 0.8921, Validation Loss: 0.7350, Validation Accuracy: 0.6000
# Epoch [25/50], Train Loss: 0.2677, Train Accuracy: 0.9309, Validation Loss: 0.7347, Validation Accuracy: 0.5941
# Epoch [26/50], Train Loss: 0.2404, Train Accuracy: 0.9309, Validation Loss: 0.7716, Validation Accuracy: 0.5706
# Epoch [27/50], Train Loss: 0.2003, Train Accuracy: 0.9545, Validation Loss: 0.7787, Validation Accuracy: 0.6059
# Epoch [28/50], Train Loss: 0.1728, Train Accuracy: 0.9612, Validation Loss: 0.8332, Validation Accuracy: 0.6118
# Epoch [29/50], Train Loss: 0.1231, Train Accuracy: 0.9848, Validation Loss: 0.8326, Validation Accuracy: 0.6118
# Epoch [30/50], Train Loss: 0.0832, Train Accuracy: 0.9983, Validation Loss: 0.9062, Validation Accuracy: 0.6059
# Epoch [31/50], Train Loss: 0.0667, Train Accuracy: 1.0000, Validation Loss: 0.9321, Validation Accuracy: 0.6235
# Epoch [32/50], Train Loss: 0.0512, Train Accuracy: 1.0000, Validation Loss: 0.9990, Validation Accuracy: 0.6059
# Epoch [33/50], Train Loss: 0.0316, Train Accuracy: 1.0000, Validation Loss: 1.0500, Validation Accuracy: 0.5882
# Epoch [34/50], Train Loss: 0.0244, Train Accuracy: 1.0000, Validation Loss: 1.0912, Validation Accuracy: 0.6118
# Epoch [35/50], Train Loss: 0.0192, Train Accuracy: 1.0000, Validation Loss: 1.1385, Validation Accuracy: 0.6000
# Epoch [36/50], Train Loss: 0.0164, Train Accuracy: 1.0000, Validation Loss: 1.1837, Validation Accuracy: 0.6000
# Epoch [37/50], Train Loss: 0.0135, Train Accuracy: 1.0000, Validation Loss: 1.2151, Validation Accuracy: 0.6235
# Epoch [38/50], Train Loss: 0.0111, Train Accuracy: 1.0000, Validation Loss: 1.2617, Validation Accuracy: 0.6059
# Epoch [39/50], Train Loss: 0.0083, Train Accuracy: 1.0000, Validation Loss: 1.2754, Validation Accuracy: 0.6118
# Epoch [40/50], Train Loss: 0.0061, Train Accuracy: 1.0000, Validation Loss: 1.2850, Validation Accuracy: 0.6176
# Epoch [41/50], Train Loss: 0.0052, Train Accuracy: 1.0000, Validation Loss: 1.3040, Validation Accuracy: 0.6176
# Early stopping triggered.
# Bestloss
# Accuracy: 0.3837
# Sensitivity: 0.3261
# Specificity: 0.4500
# Positive Predictive Value: 0.4054
# Negative Predictive Value: 0.3673
#
# Bestacc
# Accuracy: 0.5000
# Sensitivity: 0.5652
# Specificity: 0.4250
# Positive Predictive Value: 0.5306
# Negative Predictive Value: 0.4595

# %% [markdown]
# # csv

# %%
class SimpleCNN_csv(nn.Module):
    def __init__(self):
        super(SimpleCNN_csv, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# 定义超参数
input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_csv()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None
# =====================
# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(csv)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(csv)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and (acc_count >= acc_patience and epoch > 30):
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_csv_notmodify_0attention.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_csv_notmodify_0attention.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

model_save_path = "pth/model_csv_notmodify_attention.pth"
torch.save(model.state_dict(), model_save_path)
# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 1.4827, Train Accuracy: 0.5093, Validation Loss: 0.7953, Validation Accuracy: 0.4647
# Epoch [2/50], Train Loss: 0.7404, Train Accuracy: 0.4401, Validation Loss: 0.6904, Validation Accuracy: 0.5353
# Epoch [3/50], Train Loss: 0.6894, Train Accuracy: 0.5346, Validation Loss: 0.6902, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6888, Train Accuracy: 0.5346, Validation Loss: 0.6902, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6889, Train Accuracy: 0.5346, Validation Loss: 0.6903, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6887, Train Accuracy: 0.5346, Validation Loss: 0.6900, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6880, Train Accuracy: 0.5346, Validation Loss: 0.6897, Validation Accuracy: 0.5353
# Epoch [8/50], Train Loss: 0.6869, Train Accuracy: 0.5346, Validation Loss: 0.6893, Validation Accuracy: 0.5353
# Epoch [9/50], Train Loss: 0.6852, Train Accuracy: 0.5346, Validation Loss: 0.6889, Validation Accuracy: 0.5353
# Epoch [10/50], Train Loss: 0.6835, Train Accuracy: 0.5346, Validation Loss: 0.6891, Validation Accuracy: 0.5353
# Epoch [11/50], Train Loss: 0.6807, Train Accuracy: 0.5346, Validation Loss: 0.6886, Validation Accuracy: 0.5353
# Epoch [12/50], Train Loss: 0.6763, Train Accuracy: 0.5346, Validation Loss: 0.6874, Validation Accuracy: 0.5353
# Epoch [13/50], Train Loss: 0.6707, Train Accuracy: 0.5346, Validation Loss: 0.6869, Validation Accuracy: 0.5353
# Epoch [14/50], Train Loss: 0.6623, Train Accuracy: 0.5346, Validation Loss: 0.6852, Validation Accuracy: 0.5353
# Epoch [15/50], Train Loss: 0.6475, Train Accuracy: 0.5481, Validation Loss: 0.6802, Validation Accuracy: 0.5353
# Epoch [16/50], Train Loss: 0.6320, Train Accuracy: 0.7386, Validation Loss: 0.7128, Validation Accuracy: 0.5353
# Epoch [17/50], Train Loss: 0.6184, Train Accuracy: 0.6661, Validation Loss: 0.6759, Validation Accuracy: 0.6000
# Epoch [18/50], Train Loss: 0.5837, Train Accuracy: 0.7555, Validation Loss: 0.6750, Validation Accuracy: 0.5647
# Epoch [19/50], Train Loss: 0.5545, Train Accuracy: 0.8010, Validation Loss: 0.6861, Validation Accuracy: 0.5529
# Epoch [20/50], Train Loss: 0.5136, Train Accuracy: 0.8027, Validation Loss: 0.6711, Validation Accuracy: 0.6059
# Epoch [21/50], Train Loss: 0.4751, Train Accuracy: 0.8297, Validation Loss: 0.6697, Validation Accuracy: 0.5941
# Epoch [22/50], Train Loss: 0.4407, Train Accuracy: 0.8449, Validation Loss: 0.7107, Validation Accuracy: 0.5765
# Epoch [23/50], Train Loss: 0.4035, Train Accuracy: 0.8600, Validation Loss: 0.7856, Validation Accuracy: 0.5588
# Epoch [24/50], Train Loss: 0.3981, Train Accuracy: 0.8246, Validation Loss: 0.8040, Validation Accuracy: 0.5588
# Epoch [25/50], Train Loss: 0.3739, Train Accuracy: 0.8567, Validation Loss: 0.6823, Validation Accuracy: 0.5882
# Epoch [26/50], Train Loss: 0.3246, Train Accuracy: 0.9106, Validation Loss: 0.6798, Validation Accuracy: 0.6235
# Epoch [27/50], Train Loss: 0.2908, Train Accuracy: 0.9275, Validation Loss: 0.6700, Validation Accuracy: 0.5882
# Epoch [28/50], Train Loss: 0.2685, Train Accuracy: 0.9376, Validation Loss: 0.7474, Validation Accuracy: 0.6176
# Epoch [29/50], Train Loss: 0.2295, Train Accuracy: 0.9511, Validation Loss: 0.6887, Validation Accuracy: 0.6118
# Epoch [30/50], Train Loss: 0.2003, Train Accuracy: 0.9713, Validation Loss: 0.6976, Validation Accuracy: 0.6118
# Epoch [31/50], Train Loss: 0.1787, Train Accuracy: 0.9696, Validation Loss: 0.7107, Validation Accuracy: 0.6118
# Epoch [32/50], Train Loss: 0.1529, Train Accuracy: 0.9865, Validation Loss: 0.7321, Validation Accuracy: 0.5941
# Epoch [33/50], Train Loss: 0.1309, Train Accuracy: 0.9865, Validation Loss: 0.7063, Validation Accuracy: 0.6412
# Epoch [34/50], Train Loss: 0.0988, Train Accuracy: 0.9966, Validation Loss: 0.7256, Validation Accuracy: 0.6353
# Epoch [35/50], Train Loss: 0.0779, Train Accuracy: 0.9983, Validation Loss: 0.7681, Validation Accuracy: 0.6235
# Epoch [36/50], Train Loss: 0.0630, Train Accuracy: 1.0000, Validation Loss: 0.7634, Validation Accuracy: 0.6176
# Epoch [37/50], Train Loss: 0.0487, Train Accuracy: 1.0000, Validation Loss: 0.7901, Validation Accuracy: 0.6176
# Epoch [38/50], Train Loss: 0.0403, Train Accuracy: 1.0000, Validation Loss: 0.8096, Validation Accuracy: 0.6000
# Epoch [39/50], Train Loss: 0.0325, Train Accuracy: 1.0000, Validation Loss: 0.8365, Validation Accuracy: 0.6118
# Epoch [40/50], Train Loss: 0.0251, Train Accuracy: 1.0000, Validation Loss: 0.8549, Validation Accuracy: 0.6059
# Epoch [41/50], Train Loss: 0.0208, Train Accuracy: 1.0000, Validation Loss: 0.8734, Validation Accuracy: 0.6118
# Epoch [42/50], Train Loss: 0.0173, Train Accuracy: 1.0000, Validation Loss: 0.8899, Validation Accuracy: 0.6118
# Epoch [43/50], Train Loss: 0.0144, Train Accuracy: 1.0000, Validation Loss: 0.9306, Validation Accuracy: 0.6235
# Early stopping triggered.
# Bestloss
# Accuracy: 0.5000
# Sensitivity: 0.1739
# Specificity: 0.8750
# Positive Predictive Value: 0.6154
# Negative Predictive Value: 0.4795
#
# Bestacc
# Accuracy: 0.5349
# Sensitivity: 0.7826
# Specificity: 0.2500
# Positive Predictive Value: 0.5455
# Negative Predictive Value: 0.5000
