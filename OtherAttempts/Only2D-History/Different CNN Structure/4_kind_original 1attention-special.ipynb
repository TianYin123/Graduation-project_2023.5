# %%
import numpy as np
import torch
import os
import random
from torch.utils.data import Dataset
import torch.nn.functional as F
import torch.nn as nn
import nibabel as nib

import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from torch.utils.data import ConcatDataset
import torchvision.models as models
import copy

# %%
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
 
        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)
 
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, x): 
        # the shape of x is (b c h w)
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        attn = self.sigmoid(out) # (b c)
        x = x * attn[:, :, None, None]
        return x

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
 
        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1
 
        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, x): 
        # the shape of x is (b c h w)
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        attn = torch.cat([avg_out, max_out], dim=1)
        attn = self.conv1(attn) # b 1 h w
        attn = self.sigmoid(attn)
        attn = torch.squeeze(attn, dim=1) # b h w
        x = attn[:, None, :, :] * x
        return x

# %%
random.seed(3407)
rmb_label = {"ASD": 0, "TD": 1}      # 设置标签

class MultiModalDataset(Dataset):
    def __init__(self, data_dirho, data_diraal,data_direz , data_dircsv, transform=None):
        """ 
        ABIDE_db的Dataset
        :param data_dir: str, 数据集所在路径
        :param transform: torch.transform，数据预处理
        """
        self.label_name = {"ASD": 0, "TD": 1}
        self.data_infocsv = self.get_csv_info(data_dircsv)  # data_info存储所有txt路径和标签，在DataLoader中通过index读取样本
        self.data_infoez = self.get_1D_info(data_direz)  # data_info存储所有txt路径和标签，在DataLoader中通过index读取样本
        self.data_infoho = self.get_1D_info(data_dirho)
        self.data_infoaal = self.get_1D_info(data_diraal)

        self.transform = transform
        

        
    def __getitem__(self, index):
        path_csv, label_csv = self.data_infocsv[index]
        txt_data = np.loadtxt(path_csv, delimiter=',')
        label = label_csv
        csv = torch.from_numpy(txt_data).float().unsqueeze(0)
        ez = self.process_data(method='ez',index=index,labels=label_csv)
        ho = self.process_data(method='ho',index=index,labels=label_csv)
        aal = self.process_data(method='aal',index=index,labels=label_csv)

        if self.transform is not None:
            txt = 1   # 在这里做transform，转为tensor等等

        return ho,aal,ez,csv,label

    def __len__(self):
        return len(self.data_infocsv)

    @staticmethod
    def get_csv_info(data_dir):
        data_infocsv = list()
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            for sub_dir in dirs:
                txt_names = os.listdir(os.path.join(root, sub_dir))
                txt_names = list(filter(lambda x: x.endswith('.csv'), txt_names))

                # 遍历txt
                for i in range(len(txt_names)):
                    txt_name = txt_names[i]
                    path_txt = os.path.join(root, sub_dir, txt_name)
                    label = rmb_label[sub_dir]
                    data_infocsv.append((path_txt, int(label)))
                    data_infocsv = sorted(data_infocsv)

        return data_infocsv
    
    def get_1D_info(self,data_dir):
        data_infonii = list()
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            for sub_dir in dirs:
                txt_names = os.listdir(os.path.join(root, sub_dir))
                txt_names = list(filter(lambda x: x.endswith('.1D'), txt_names))

                # 遍历txt
                for i in range(len(txt_names)):
                    txt_name = txt_names[i]
                    path_txt = os.path.join(root, sub_dir, txt_name)
                    label = rmb_label[sub_dir]
                    data_infonii.append((path_txt, int(label)))
                    data_infonii = sorted(data_infonii)
        return data_infonii
    
    def process_data(self,method,index,labels):
        if method == 'ez':
            path, label = self.data_infoez[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            cor = torch.from_numpy(cor).float().unsqueeze(0)
        if method == 'ho':
            path, label = self.data_infoho[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            file1 = np.pad(cor, ((0, 5), (0, 5)), mode='constant')
            cor = torch.from_numpy(file1).float().unsqueeze(0)
        if method == 'aal':
            path, label = self.data_infoaal[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            cor = torch.from_numpy(cor).float().unsqueeze(0)
        if labels != label:
            print('Error: label not match!')
            print('the error 1D:{}',path)
        
        
        return cor

# %%
class SimpleCNN_aal(nn.Module):
    def __init__(self):
        super(SimpleCNN_aal, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)
    
        self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        # x = self.channel_attention2(x)
        x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
csv_split_dir = os.path.join('easy/not modify/csv_split')  
csv_train_dir = os.path.join(csv_split_dir, "train")
csv_valid_dir = os.path.join(csv_split_dir, "valid")
csv_test_dir  = os.path.join(csv_split_dir, "test") 
aal_split_dir = os.path.join('easy/not modify/aal_split')  
aal_train_dir = os.path.join(aal_split_dir, "train")
aal_valid_dir = os.path.join(aal_split_dir, "valid")
aal_test_dir  = os.path.join(aal_split_dir, "test") 
ho_split_dir = os.path.join('easy/not modify/rho_split')  
ho_train_dir = os.path.join(ho_split_dir, "train")
ho_valid_dir = os.path.join(ho_split_dir, "valid")
ho_test_dir  = os.path.join(ho_split_dir, "test") 
ez_split_dir = os.path.join('easy/not modify/ez_split')  
ez_train_dir = os.path.join(ez_split_dir, "train")
ez_valid_dir = os.path.join(ez_split_dir, "valid")
ez_test_dir  = os.path.join(ez_split_dir, "test")

# %% [markdown]
# # aal

# %%
#aal
# 定义超参数

input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 70
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_aal()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
# 初始化
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None

# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(aal)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(aal)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_aal_notmodify_1attention_special.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_aal_notmodify_1attention_special.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/70], Train Loss: 0.9233, Train Accuracy: 0.5025, Validation Loss: 0.7631, Validation Accuracy: 0.4647
# Epoch [2/70], Train Loss: 0.7113, Train Accuracy: 0.4840, Validation Loss: 0.6922, Validation Accuracy: 0.5353
# Epoch [3/70], Train Loss: 0.6919, Train Accuracy: 0.5346, Validation Loss: 0.6913, Validation Accuracy: 0.5353
# Epoch [4/70], Train Loss: 0.6902, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [5/70], Train Loss: 0.6899, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [6/70], Train Loss: 0.6902, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [7/70], Train Loss: 0.6901, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [8/70], Train Loss: 0.6898, Train Accuracy: 0.5346, Validation Loss: 0.6904, Validation Accuracy: 0.5353
# Epoch [9/70], Train Loss: 0.6890, Train Accuracy: 0.5346, Validation Loss: 0.6901, Validation Accuracy: 0.5353
# Epoch [10/70], Train Loss: 0.6875, Train Accuracy: 0.5346, Validation Loss: 0.6898, Validation Accuracy: 0.5353
# Epoch [11/70], Train Loss: 0.6851, Train Accuracy: 0.5346, Validation Loss: 0.6892, Validation Accuracy: 0.5353
# Epoch [12/70], Train Loss: 0.6834, Train Accuracy: 0.5346, Validation Loss: 0.6884, Validation Accuracy: 0.5353
# Epoch [13/70], Train Loss: 0.6774, Train Accuracy: 0.5346, Validation Loss: 0.6868, Validation Accuracy: 0.5353
# Epoch [14/70], Train Loss: 0.6716, Train Accuracy: 0.5396, Validation Loss: 0.6852, Validation Accuracy: 0.5471
# Epoch [15/70], Train Loss: 0.6664, Train Accuracy: 0.6577, Validation Loss: 0.6835, Validation Accuracy: 0.5529
# Epoch [16/70], Train Loss: 0.6553, Train Accuracy: 0.6391, Validation Loss: 0.6814, Validation Accuracy: 0.5471
# Epoch [17/70], Train Loss: 0.6438, Train Accuracy: 0.6762, Validation Loss: 0.6793, Validation Accuracy: 0.5529
# Epoch [18/70], Train Loss: 0.6351, Train Accuracy: 0.6577, Validation Loss: 0.6768, Validation Accuracy: 0.5471
# Epoch [19/70], Train Loss: 0.6126, Train Accuracy: 0.6998, Validation Loss: 0.6764, Validation Accuracy: 0.5471
# Epoch [20/70], Train Loss: 0.6026, Train Accuracy: 0.7015, Validation Loss: 0.7257, Validation Accuracy: 0.5588
# Epoch [21/70], Train Loss: 0.6043, Train Accuracy: 0.6425, Validation Loss: 0.6928, Validation Accuracy: 0.5471
# Epoch [22/70], Train Loss: 0.5964, Train Accuracy: 0.6813, Validation Loss: 0.6833, Validation Accuracy: 0.5647
# Epoch [23/70], Train Loss: 0.5693, Train Accuracy: 0.7234, Validation Loss: 0.6818, Validation Accuracy: 0.5588
# Epoch [24/70], Train Loss: 0.5445, Train Accuracy: 0.7538, Validation Loss: 0.6814, Validation Accuracy: 0.5706
# Epoch [25/70], Train Loss: 0.5263, Train Accuracy: 0.7487, Validation Loss: 0.6776, Validation Accuracy: 0.6176
# Epoch [26/70], Train Loss: 0.4995, Train Accuracy: 0.7690, Validation Loss: 0.6871, Validation Accuracy: 0.5941
# Epoch [27/70], Train Loss: 0.4752, Train Accuracy: 0.7808, Validation Loss: 0.6873, Validation Accuracy: 0.6000
# Epoch [28/70], Train Loss: 0.4456, Train Accuracy: 0.7976, Validation Loss: 0.6783, Validation Accuracy: 0.6294
# Epoch [29/70], Train Loss: 0.4030, Train Accuracy: 0.8381, Validation Loss: 0.7106, Validation Accuracy: 0.6000
# Epoch [30/70], Train Loss: 0.3983, Train Accuracy: 0.8347, Validation Loss: 0.7247, Validation Accuracy: 0.6059
# Epoch [31/70], Train Loss: 0.3371, Train Accuracy: 0.8752, Validation Loss: 0.6981, Validation Accuracy: 0.6294
# Epoch [32/70], Train Loss: 0.2911, Train Accuracy: 0.9005, Validation Loss: 0.7570, Validation Accuracy: 0.6176
# Epoch [33/70], Train Loss: 0.2671, Train Accuracy: 0.8938, Validation Loss: 0.7603, Validation Accuracy: 0.6353
# Epoch [34/70], Train Loss: 0.2199, Train Accuracy: 0.9325, Validation Loss: 0.9067, Validation Accuracy: 0.5941
# Epoch [35/70], Train Loss: 0.2037, Train Accuracy: 0.9325, Validation Loss: 0.8538, Validation Accuracy: 0.5824
# Epoch [36/70], Train Loss: 0.1570, Train Accuracy: 0.9578, Validation Loss: 0.8970, Validation Accuracy: 0.6118
# Epoch [37/70], Train Loss: 0.1249, Train Accuracy: 0.9764, Validation Loss: 0.9277, Validation Accuracy: 0.6059
# Epoch [38/70], Train Loss: 0.1001, Train Accuracy: 0.9865, Validation Loss: 0.9425, Validation Accuracy: 0.6235
# Epoch [39/70], Train Loss: 0.0746, Train Accuracy: 0.9916, Validation Loss: 1.0126, Validation Accuracy: 0.5824
# Epoch [40/70], Train Loss: 0.0492, Train Accuracy: 1.0000, Validation Loss: 1.0060, Validation Accuracy: 0.6059
# Epoch [41/70], Train Loss: 0.0342, Train Accuracy: 1.0000, Validation Loss: 1.0593, Validation Accuracy: 0.6000
# Epoch [42/70], Train Loss: 0.0277, Train Accuracy: 1.0000, Validation Loss: 1.1022, Validation Accuracy: 0.5941
# Epoch [43/70], Train Loss: 0.0209, Train Accuracy: 1.0000, Validation Loss: 1.1538, Validation Accuracy: 0.5941
# Early stopping triggered.
# Bestloss
# Accuracy: 0.5233
# Sensitivity: 0.6087
# Specificity: 0.4250
# Positive Predictive Value: 0.5490
# Negative Predictive Value: 0.4857
#
# Bestacc
# Accuracy: 0.5233
# Sensitivity: 0.6087
# Specificity: 0.4250
# Positive Predictive Value: 0.5490
# Negative Predictive Value: 0.4857

# %% [markdown]
# # Ho

# %%
class SimpleCNN_ho(nn.Module):
    def __init__(self):
        super(SimpleCNN_ho, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)
    
        self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        # x = self.channel_attention2(x)
        x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
#aal
# 定义超参数

input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_ho()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
# 初始化
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None

# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(ho)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(ho)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_ho_notmodify_1attention_special.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_ho_notmodify_1attention_special.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 0.8216, Train Accuracy: 0.4924, Validation Loss: 0.7633, Validation Accuracy: 0.4647
# Epoch [2/50], Train Loss: 0.7223, Train Accuracy: 0.4654, Validation Loss: 0.6935, Validation Accuracy: 0.4647
# Epoch [3/50], Train Loss: 0.6931, Train Accuracy: 0.4874, Validation Loss: 0.6917, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6915, Train Accuracy: 0.5346, Validation Loss: 0.6907, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6904, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6900, Train Accuracy: 0.5346, Validation Loss: 0.6904, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6897, Train Accuracy: 0.5346, Validation Loss: 0.6907, Validation Accuracy: 0.5353
# Epoch [8/50], Train Loss: 0.6877, Train Accuracy: 0.5346, Validation Loss: 0.6909, Validation Accuracy: 0.5353
# Epoch [9/50], Train Loss: 0.6894, Train Accuracy: 0.5346, Validation Loss: 0.6898, Validation Accuracy: 0.5353
# Epoch [10/50], Train Loss: 0.6834, Train Accuracy: 0.6206, Validation Loss: 0.6912, Validation Accuracy: 0.6000
# Epoch [11/50], Train Loss: 0.6809, Train Accuracy: 0.6223, Validation Loss: 0.6884, Validation Accuracy: 0.5353
# Epoch [12/50], Train Loss: 0.6726, Train Accuracy: 0.5430, Validation Loss: 0.6883, Validation Accuracy: 0.5353
# Epoch [13/50], Train Loss: 0.6639, Train Accuracy: 0.5852, Validation Loss: 0.6864, Validation Accuracy: 0.5353
# Epoch [14/50], Train Loss: 0.6508, Train Accuracy: 0.6358, Validation Loss: 0.6842, Validation Accuracy: 0.5706
# Epoch [15/50], Train Loss: 0.6337, Train Accuracy: 0.6728, Validation Loss: 0.6912, Validation Accuracy: 0.5353
# Epoch [16/50], Train Loss: 0.6189, Train Accuracy: 0.6695, Validation Loss: 0.6945, Validation Accuracy: 0.5176
# Epoch [17/50], Train Loss: 0.5915, Train Accuracy: 0.7083, Validation Loss: 0.7263, Validation Accuracy: 0.5471
# Epoch [18/50], Train Loss: 0.5966, Train Accuracy: 0.6745, Validation Loss: 0.6947, Validation Accuracy: 0.5647
# Epoch [19/50], Train Loss: 0.5729, Train Accuracy: 0.7015, Validation Loss: 0.6976, Validation Accuracy: 0.5412
# Epoch [20/50], Train Loss: 0.5559, Train Accuracy: 0.7251, Validation Loss: 0.7116, Validation Accuracy: 0.5588
# Epoch [21/50], Train Loss: 0.5388, Train Accuracy: 0.7369, Validation Loss: 0.7087, Validation Accuracy: 0.5882
# Epoch [22/50], Train Loss: 0.5219, Train Accuracy: 0.7605, Validation Loss: 0.7461, Validation Accuracy: 0.5529
# Epoch [23/50], Train Loss: 0.5095, Train Accuracy: 0.7555, Validation Loss: 0.7297, Validation Accuracy: 0.5706
# Epoch [24/50], Train Loss: 0.4713, Train Accuracy: 0.7808, Validation Loss: 0.7319, Validation Accuracy: 0.5706
# Early stopping triggered.
# Bestloss
# Accuracy: 0.6744
# Sensitivity: 0.6304
# Specificity: 0.7250
# Positive Predictive Value: 0.7250
# Negative Predictive Value: 0.6304
#
# Bestacc
# Accuracy: 0.4419
# Sensitivity: 0.1739
# Specificity: 0.7500
# Positive Predictive Value: 0.4444
# Negative Predictive Value: 0.4412

# %% [markdown]
# # ez

# %%
class SimpleCNN_ez(nn.Module):
    def __init__(self):
        super(SimpleCNN_ez, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)
    
        self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        # x = self.channel_attention2(x)
        x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# 定义超参数
input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_ez()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None
# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(ez)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(ez)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_ez_notmodify_1attention_special.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_ez_notmodify_1attention_special.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 1.0115, Train Accuracy: 0.4958, Validation Loss: 0.7989, Validation Accuracy: 0.4647
# Epoch [2/50], Train Loss: 0.7363, Train Accuracy: 0.4671, Validation Loss: 0.6911, Validation Accuracy: 0.5353
# Epoch [3/50], Train Loss: 0.7008, Train Accuracy: 0.5346, Validation Loss: 0.6987, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6952, Train Accuracy: 0.5346, Validation Loss: 0.6915, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6917, Train Accuracy: 0.5346, Validation Loss: 0.6907, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6909, Train Accuracy: 0.5346, Validation Loss: 0.6911, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6907, Train Accuracy: 0.5346, Validation Loss: 0.6904, Validation Accuracy: 0.5353
# Epoch [8/50], Train Loss: 0.6893, Train Accuracy: 0.5346, Validation Loss: 0.6902, Validation Accuracy: 0.5353
# Epoch [9/50], Train Loss: 0.6886, Train Accuracy: 0.5346, Validation Loss: 0.6899, Validation Accuracy: 0.5353
# Epoch [10/50], Train Loss: 0.6873, Train Accuracy: 0.5346, Validation Loss: 0.6899, Validation Accuracy: 0.5353
# Epoch [11/50], Train Loss: 0.6854, Train Accuracy: 0.5346, Validation Loss: 0.6893, Validation Accuracy: 0.5353
# Epoch [12/50], Train Loss: 0.6834, Train Accuracy: 0.5346, Validation Loss: 0.6883, Validation Accuracy: 0.5353
# Epoch [13/50], Train Loss: 0.6780, Train Accuracy: 0.5346, Validation Loss: 0.6871, Validation Accuracy: 0.5353
# Epoch [14/50], Train Loss: 0.6717, Train Accuracy: 0.5396, Validation Loss: 0.6854, Validation Accuracy: 0.5529
# Epoch [15/50], Train Loss: 0.6655, Train Accuracy: 0.7049, Validation Loss: 0.6831, Validation Accuracy: 0.5412
# Epoch [16/50], Train Loss: 0.6513, Train Accuracy: 0.5649, Validation Loss: 0.6818, Validation Accuracy: 0.5471
# Epoch [17/50], Train Loss: 0.6367, Train Accuracy: 0.7015, Validation Loss: 0.6782, Validation Accuracy: 0.5706
# Epoch [18/50], Train Loss: 0.6181, Train Accuracy: 0.7319, Validation Loss: 0.6754, Validation Accuracy: 0.5529
# Epoch [19/50], Train Loss: 0.5982, Train Accuracy: 0.7201, Validation Loss: 0.6797, Validation Accuracy: 0.5706
# Epoch [20/50], Train Loss: 0.5687, Train Accuracy: 0.7589, Validation Loss: 0.6775, Validation Accuracy: 0.5471
# Epoch [21/50], Train Loss: 0.5490, Train Accuracy: 0.7723, Validation Loss: 0.6957, Validation Accuracy: 0.5471
# Epoch [22/50], Train Loss: 0.5364, Train Accuracy: 0.7454, Validation Loss: 0.6770, Validation Accuracy: 0.5647
# Epoch [23/50], Train Loss: 0.5184, Train Accuracy: 0.7538, Validation Loss: 0.6849, Validation Accuracy: 0.6059
# Epoch [24/50], Train Loss: 0.4766, Train Accuracy: 0.8078, Validation Loss: 0.6734, Validation Accuracy: 0.5647
# Epoch [25/50], Train Loss: 0.4471, Train Accuracy: 0.8364, Validation Loss: 0.6634, Validation Accuracy: 0.6059
# Epoch [26/50], Train Loss: 0.4176, Train Accuracy: 0.8550, Validation Loss: 0.6751, Validation Accuracy: 0.6059
# Epoch [27/50], Train Loss: 0.3842, Train Accuracy: 0.8550, Validation Loss: 0.7183, Validation Accuracy: 0.5941
# Epoch [28/50], Train Loss: 0.3573, Train Accuracy: 0.8803, Validation Loss: 0.6895, Validation Accuracy: 0.6235
# Epoch [29/50], Train Loss: 0.3240, Train Accuracy: 0.8904, Validation Loss: 0.7944, Validation Accuracy: 0.6059
# Epoch [30/50], Train Loss: 0.3323, Train Accuracy: 0.8567, Validation Loss: 0.7686, Validation Accuracy: 0.6059
# Epoch [31/50], Train Loss: 0.2790, Train Accuracy: 0.9022, Validation Loss: 0.7234, Validation Accuracy: 0.6059
# Epoch [32/50], Train Loss: 0.2400, Train Accuracy: 0.9393, Validation Loss: 0.7843, Validation Accuracy: 0.5824
# Epoch [33/50], Train Loss: 0.2107, Train Accuracy: 0.9444, Validation Loss: 0.7840, Validation Accuracy: 0.6000
# Epoch [34/50], Train Loss: 0.1698, Train Accuracy: 0.9680, Validation Loss: 0.8407, Validation Accuracy: 0.5941
# Epoch [35/50], Train Loss: 0.1501, Train Accuracy: 0.9696, Validation Loss: 0.8480, Validation Accuracy: 0.6176
# Epoch [36/50], Train Loss: 0.1123, Train Accuracy: 0.9848, Validation Loss: 0.8637, Validation Accuracy: 0.6059
# Epoch [37/50], Train Loss: 0.0881, Train Accuracy: 0.9949, Validation Loss: 0.9152, Validation Accuracy: 0.5941
# Epoch [38/50], Train Loss: 0.0686, Train Accuracy: 0.9916, Validation Loss: 1.1123, Validation Accuracy: 0.6176
# Early stopping triggered.
# Bestloss
# Accuracy: 0.4419
# Sensitivity: 0.0000
# Specificity: 0.9500
# Positive Predictive Value: 0.0000
# Negative Predictive Value: 0.4524
#
# Bestacc
# Accuracy: 0.5465
# Sensitivity: 0.3261
# Specificity: 0.8000
# Positive Predictive Value: 0.6522
# Negative Predictive Value: 0.5079

# %% [markdown]
# # csv

# %%
class SimpleCNN_csv(nn.Module):
    def __init__(self):
        super(SimpleCNN_csv, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)
    
        self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        # x = self.channel_attention2(x)
        x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# 定义超参数
input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_csv()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None
# =====================
# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(csv)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(csv)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and (acc_count >= acc_patience and epoch > 30):
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_csv_notmodify_1attention_special.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_csv_notmodify_1attention_special.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

model_save_path = "pth/model_csv_notmodify_attention.pth"
torch.save(model.state_dict(), model_save_path)
# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 1.0798, Train Accuracy: 0.5160, Validation Loss: 0.7896, Validation Accuracy: 0.4647
# Epoch [2/50], Train Loss: 0.7221, Train Accuracy: 0.4739, Validation Loss: 0.7094, Validation Accuracy: 0.5353
# Epoch [3/50], Train Loss: 0.7050, Train Accuracy: 0.5346, Validation Loss: 0.6983, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6926, Train Accuracy: 0.5346, Validation Loss: 0.6914, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6890, Train Accuracy: 0.5346, Validation Loss: 0.6905, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6892, Train Accuracy: 0.5346, Validation Loss: 0.6902, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6892, Train Accuracy: 0.5346, Validation Loss: 0.6904, Validation Accuracy: 0.5353
# Epoch [8/50], Train Loss: 0.6881, Train Accuracy: 0.5346, Validation Loss: 0.6902, Validation Accuracy: 0.5353
# Epoch [9/50], Train Loss: 0.6874, Train Accuracy: 0.5346, Validation Loss: 0.6899, Validation Accuracy: 0.5353
# Epoch [10/50], Train Loss: 0.6858, Train Accuracy: 0.5346, Validation Loss: 0.6897, Validation Accuracy: 0.5353
# Epoch [11/50], Train Loss: 0.6839, Train Accuracy: 0.5346, Validation Loss: 0.6893, Validation Accuracy: 0.5353
# Epoch [12/50], Train Loss: 0.6810, Train Accuracy: 0.5346, Validation Loss: 0.6885, Validation Accuracy: 0.5353
# Epoch [13/50], Train Loss: 0.6766, Train Accuracy: 0.5430, Validation Loss: 0.6874, Validation Accuracy: 0.5412
# Epoch [14/50], Train Loss: 0.6708, Train Accuracy: 0.6020, Validation Loss: 0.6861, Validation Accuracy: 0.5529
# Epoch [15/50], Train Loss: 0.6624, Train Accuracy: 0.6644, Validation Loss: 0.6840, Validation Accuracy: 0.5412
# Epoch [16/50], Train Loss: 0.6523, Train Accuracy: 0.7150, Validation Loss: 0.6814, Validation Accuracy: 0.5353
# Epoch [17/50], Train Loss: 0.6376, Train Accuracy: 0.7825, Validation Loss: 0.6791, Validation Accuracy: 0.5471
# Epoch [18/50], Train Loss: 0.6223, Train Accuracy: 0.7437, Validation Loss: 0.6758, Validation Accuracy: 0.5412
# Epoch [19/50], Train Loss: 0.6073, Train Accuracy: 0.7639, Validation Loss: 0.6824, Validation Accuracy: 0.5647
# Epoch [20/50], Train Loss: 0.5917, Train Accuracy: 0.6847, Validation Loss: 0.6822, Validation Accuracy: 0.5588
# Epoch [21/50], Train Loss: 0.5718, Train Accuracy: 0.7352, Validation Loss: 0.6743, Validation Accuracy: 0.5353
# Epoch [22/50], Train Loss: 0.5344, Train Accuracy: 0.8078, Validation Loss: 0.6732, Validation Accuracy: 0.5941
# Epoch [23/50], Train Loss: 0.5168, Train Accuracy: 0.7858, Validation Loss: 0.6801, Validation Accuracy: 0.5941
# Epoch [24/50], Train Loss: 0.5053, Train Accuracy: 0.7841, Validation Loss: 0.6725, Validation Accuracy: 0.5706
# Epoch [25/50], Train Loss: 0.4632, Train Accuracy: 0.8229, Validation Loss: 0.6979, Validation Accuracy: 0.5588
# Epoch [26/50], Train Loss: 0.4403, Train Accuracy: 0.8364, Validation Loss: 0.6668, Validation Accuracy: 0.5824
# Epoch [27/50], Train Loss: 0.3953, Train Accuracy: 0.8735, Validation Loss: 0.7180, Validation Accuracy: 0.5941
# Epoch [28/50], Train Loss: 0.4073, Train Accuracy: 0.8196, Validation Loss: 0.6692, Validation Accuracy: 0.6000
# Epoch [29/50], Train Loss: 0.3514, Train Accuracy: 0.8938, Validation Loss: 0.7217, Validation Accuracy: 0.5941
# Epoch [30/50], Train Loss: 0.2965, Train Accuracy: 0.9123, Validation Loss: 0.6759, Validation Accuracy: 0.6176
# Epoch [31/50], Train Loss: 0.2657, Train Accuracy: 0.9275, Validation Loss: 0.6961, Validation Accuracy: 0.6118
# Epoch [32/50], Train Loss: 0.2301, Train Accuracy: 0.9275, Validation Loss: 0.7216, Validation Accuracy: 0.6294
# Epoch [33/50], Train Loss: 0.1780, Train Accuracy: 0.9612, Validation Loss: 0.7976, Validation Accuracy: 0.6176
# Epoch [34/50], Train Loss: 0.1284, Train Accuracy: 0.9882, Validation Loss: 0.8768, Validation Accuracy: 0.6176
# Epoch [35/50], Train Loss: 0.0918, Train Accuracy: 0.9933, Validation Loss: 0.8737, Validation Accuracy: 0.6118
# Epoch [36/50], Train Loss: 0.0626, Train Accuracy: 0.9983, Validation Loss: 0.9316, Validation Accuracy: 0.6176
# Epoch [37/50], Train Loss: 0.0535, Train Accuracy: 0.9966, Validation Loss: 0.9870, Validation Accuracy: 0.6118
# Epoch [38/50], Train Loss: 0.0313, Train Accuracy: 1.0000, Validation Loss: 1.0286, Validation Accuracy: 0.6235
# Epoch [39/50], Train Loss: 0.0214, Train Accuracy: 1.0000, Validation Loss: 1.0856, Validation Accuracy: 0.6059
# Epoch [40/50], Train Loss: 0.0162, Train Accuracy: 1.0000, Validation Loss: 1.1364, Validation Accuracy: 0.6118
# Epoch [41/50], Train Loss: 0.0119, Train Accuracy: 1.0000, Validation Loss: 1.1737, Validation Accuracy: 0.6118
# Epoch [42/50], Train Loss: 0.0097, Train Accuracy: 1.0000, Validation Loss: 1.2051, Validation Accuracy: 0.6000
# Early stopping triggered.
# Bestloss
# Accuracy: 0.5465
# Sensitivity: 0.3478
# Specificity: 0.7750
# Positive Predictive Value: 0.6400
# Negative Predictive Value: 0.5082
#
# Bestacc
# Accuracy: 0.6047
# Sensitivity: 0.6957
# Specificity: 0.5000
# Positive Predictive Value: 0.6154
# Negative Predictive Value: 0.5882
