# %%
import numpy as np
import torch
import os
import random
from torch.utils.data import Dataset
import torch.nn.functional as F
import torch.nn as nn
import nibabel as nib

import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from torch.utils.data import ConcatDataset
import torchvision.models as models
import copy

# %%
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
 
        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)
 
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, x): 
        # the shape of x is (b c h w)
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        attn = self.sigmoid(out) # (b c)
        attn = torch.squeeze(attn, dim=3)
        attn = torch.squeeze(attn, dim=2)
        x = x * attn[:, :, None, None]
        return x
    
class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
 
        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1
 
        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, x): 
        # the shape of x is (b c h w)
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        attn = torch.cat([avg_out, max_out], dim=1)
        attn = self.conv1(attn) # b 1 h w
        attn = self.sigmoid(attn)
        attn = torch.squeeze(attn, dim=1) # b h w
        x = attn[:, None, :, :] * x
        return x

# %%
random.seed(3407)
rmb_label = {"ASD": 0, "TD": 1}      # 设置标签

class MultiModalDataset(Dataset):
    def __init__(self, data_dirho, data_diraal,data_direz , data_dircsv, transform=None):
        """ 
        ABIDE_db的Dataset
        :param data_dir: str, 数据集所在路径
        :param transform: torch.transform，数据预处理
        """
        self.label_name = {"ASD": 0, "TD": 1}
        self.data_infocsv = self.get_csv_info(data_dircsv)  # data_info存储所有txt路径和标签，在DataLoader中通过index读取样本
        self.data_infoez = self.get_1D_info(data_direz)  # data_info存储所有txt路径和标签，在DataLoader中通过index读取样本
        self.data_infoho = self.get_1D_info(data_dirho)
        self.data_infoaal = self.get_1D_info(data_diraal)

        self.transform = transform
        

        
    def __getitem__(self, index):
        path_csv, label_csv = self.data_infocsv[index]
        txt_data = np.loadtxt(path_csv, delimiter=',')
        label = label_csv
        csv = torch.from_numpy(txt_data).float().unsqueeze(0)
        ez = self.process_data(method='ez',index=index,labels=label_csv)
        ho = self.process_data(method='ho',index=index,labels=label_csv)
        aal = self.process_data(method='aal',index=index,labels=label_csv)

        if self.transform is not None:
            txt = 1   # 在这里做transform，转为tensor等等

        return ho,aal,ez,csv,label

    def __len__(self):
        return len(self.data_infocsv)

    @staticmethod
    def get_csv_info(data_dir):
        data_infocsv = list()
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            for sub_dir in dirs:
                txt_names = os.listdir(os.path.join(root, sub_dir))
                txt_names = list(filter(lambda x: x.endswith('.csv'), txt_names))

                # 遍历txt
                for i in range(len(txt_names)):
                    txt_name = txt_names[i]
                    path_txt = os.path.join(root, sub_dir, txt_name)
                    label = rmb_label[sub_dir]
                    data_infocsv.append((path_txt, int(label)))
                    data_infocsv = sorted(data_infocsv)

        return data_infocsv
    
    def get_1D_info(self,data_dir):
        data_infonii = list()
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            for sub_dir in dirs:
                txt_names = os.listdir(os.path.join(root, sub_dir))
                txt_names = list(filter(lambda x: x.endswith('.1D'), txt_names))

                # 遍历txt
                for i in range(len(txt_names)):
                    txt_name = txt_names[i]
                    path_txt = os.path.join(root, sub_dir, txt_name)
                    label = rmb_label[sub_dir]
                    data_infonii.append((path_txt, int(label)))
                    data_infonii = sorted(data_infonii)
        return data_infonii
    
    def process_data(self,method,index,labels):
        if method == 'ez':
            path, label = self.data_infoez[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            cor = torch.from_numpy(cor).float().unsqueeze(0)
        if method == 'ho':
            path, label = self.data_infoho[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            file1 = np.pad(cor, ((0, 5), (0, 5)), mode='constant')
            cor = torch.from_numpy(file1).float().unsqueeze(0)
        if method == 'aal':
            path, label = self.data_infoaal[index]
            txt_data = np.loadtxt(path)
            cor = np.corrcoef(txt_data.T)
            cor = torch.from_numpy(cor).float().unsqueeze(0)
        if labels != label:
            print('Error: label not match!')
            print('the error 1D:{}',path)
        
        
        return cor

# %%
class SimpleCNN_aal(nn.Module):
    def __init__(self):
        super(SimpleCNN_aal, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)

        self.channel_attention2 = ChannelAttention(32)
    
        # self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        x = self.channel_attention2(x)
        # x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
csv_split_dir = os.path.join('easy/not modify/csv_split')  
csv_train_dir = os.path.join(csv_split_dir, "train")
csv_valid_dir = os.path.join(csv_split_dir, "valid")
csv_test_dir  = os.path.join(csv_split_dir, "test") 
aal_split_dir = os.path.join('easy/not modify/aal_split')  
aal_train_dir = os.path.join(aal_split_dir, "train")
aal_valid_dir = os.path.join(aal_split_dir, "valid")
aal_test_dir  = os.path.join(aal_split_dir, "test") 
ho_split_dir = os.path.join('easy/not modify/rho_split')  
ho_train_dir = os.path.join(ho_split_dir, "train")
ho_valid_dir = os.path.join(ho_split_dir, "valid")
ho_test_dir  = os.path.join(ho_split_dir, "test") 
ez_split_dir = os.path.join('easy/not modify/ez_split')  
ez_train_dir = os.path.join(ez_split_dir, "train")
ez_valid_dir = os.path.join(ez_split_dir, "valid")
ez_test_dir  = os.path.join(ez_split_dir, "test")

# %% [markdown]
# # aal

# %%
#aal
# 定义超参数

input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 70
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_aal()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
# 初始化
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None

# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(aal)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(aal)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_aal_notmodify_attention_channel.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_aal_notmodify_attention_channel.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/70], Train Loss: 0.8761, Train Accuracy: 0.4688, Validation Loss: 0.6948, Validation Accuracy: 0.4647
# Epoch [2/70], Train Loss: 0.6939, Train Accuracy: 0.4823, Validation Loss: 0.6909, Validation Accuracy: 0.5353
# Epoch [3/70], Train Loss: 0.6905, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [4/70], Train Loss: 0.6905, Train Accuracy: 0.5346, Validation Loss: 0.6905, Validation Accuracy: 0.5353
# Epoch [5/70], Train Loss: 0.6904, Train Accuracy: 0.5346, Validation Loss: 0.6906, Validation Accuracy: 0.5353
# Epoch [6/70], Train Loss: 0.6887, Train Accuracy: 0.5346, Validation Loss: 0.6901, Validation Accuracy: 0.5353
# Epoch [7/70], Train Loss: 0.6875, Train Accuracy: 0.5346, Validation Loss: 0.6898, Validation Accuracy: 0.5353
# Epoch [8/70], Train Loss: 0.6881, Train Accuracy: 0.5346, Validation Loss: 0.6897, Validation Accuracy: 0.5353
# Epoch [9/70], Train Loss: 0.6840, Train Accuracy: 0.5346, Validation Loss: 0.6887, Validation Accuracy: 0.5353
# Epoch [10/70], Train Loss: 0.6826, Train Accuracy: 0.5379, Validation Loss: 0.6876, Validation Accuracy: 0.5353
# Epoch [11/70], Train Loss: 0.6759, Train Accuracy: 0.5346, Validation Loss: 0.6866, Validation Accuracy: 0.5353
# Epoch [12/70], Train Loss: 0.6746, Train Accuracy: 0.5346, Validation Loss: 0.6854, Validation Accuracy: 0.5529
# Epoch [13/70], Train Loss: 0.6703, Train Accuracy: 0.6105, Validation Loss: 0.6859, Validation Accuracy: 0.5765
# Epoch [14/70], Train Loss: 0.6562, Train Accuracy: 0.6391, Validation Loss: 0.6839, Validation Accuracy: 0.5471
# Epoch [15/70], Train Loss: 0.6409, Train Accuracy: 0.6459, Validation Loss: 0.6771, Validation Accuracy: 0.5706
# Epoch [16/70], Train Loss: 0.6227, Train Accuracy: 0.6813, Validation Loss: 0.6701, Validation Accuracy: 0.5647
# Epoch [17/70], Train Loss: 0.6131, Train Accuracy: 0.6830, Validation Loss: 0.6945, Validation Accuracy: 0.5529
# Epoch [18/70], Train Loss: 0.5945, Train Accuracy: 0.6863, Validation Loss: 0.6778, Validation Accuracy: 0.6059
# Epoch [19/70], Train Loss: 0.5632, Train Accuracy: 0.7740, Validation Loss: 0.6837, Validation Accuracy: 0.5529
# Epoch [20/70], Train Loss: 0.5398, Train Accuracy: 0.7234, Validation Loss: 0.7568, Validation Accuracy: 0.5294
# Epoch [21/70], Train Loss: 0.5516, Train Accuracy: 0.7133, Validation Loss: 0.7165, Validation Accuracy: 0.5412
# Epoch [22/70], Train Loss: 0.5154, Train Accuracy: 0.7352, Validation Loss: 0.6923, Validation Accuracy: 0.6000
# Epoch [23/70], Train Loss: 0.4899, Train Accuracy: 0.7825, Validation Loss: 0.6921, Validation Accuracy: 0.5529
# Epoch [24/70], Train Loss: 0.4730, Train Accuracy: 0.7875, Validation Loss: 0.6602, Validation Accuracy: 0.6176
# Epoch [25/70], Train Loss: 0.4401, Train Accuracy: 0.8347, Validation Loss: 0.7228, Validation Accuracy: 0.5824
# Epoch [26/70], Train Loss: 0.4426, Train Accuracy: 0.8027, Validation Loss: 0.6589, Validation Accuracy: 0.6176
# Epoch [27/70], Train Loss: 0.3844, Train Accuracy: 0.8617, Validation Loss: 0.6735, Validation Accuracy: 0.6294
# Epoch [28/70], Train Loss: 0.3826, Train Accuracy: 0.8449, Validation Loss: 0.6737, Validation Accuracy: 0.6235
# Epoch [29/70], Train Loss: 0.3505, Train Accuracy: 0.8550, Validation Loss: 0.7310, Validation Accuracy: 0.6118
# Epoch [30/70], Train Loss: 0.3279, Train Accuracy: 0.8752, Validation Loss: 0.6658, Validation Accuracy: 0.6412
# Epoch [31/70], Train Loss: 0.2846, Train Accuracy: 0.9174, Validation Loss: 0.6735, Validation Accuracy: 0.6235
# Epoch [32/70], Train Loss: 0.2477, Train Accuracy: 0.9376, Validation Loss: 0.6835, Validation Accuracy: 0.6353
# Epoch [33/70], Train Loss: 0.2160, Train Accuracy: 0.9545, Validation Loss: 0.7032, Validation Accuracy: 0.6294
# Epoch [34/70], Train Loss: 0.1880, Train Accuracy: 0.9629, Validation Loss: 0.8371, Validation Accuracy: 0.6353
# Epoch [35/70], Train Loss: 0.2140, Train Accuracy: 0.9174, Validation Loss: 0.7360, Validation Accuracy: 0.6647
# Epoch [36/70], Train Loss: 0.1509, Train Accuracy: 0.9747, Validation Loss: 0.7441, Validation Accuracy: 0.6353
# Epoch [37/70], Train Loss: 0.1311, Train Accuracy: 0.9831, Validation Loss: 0.7533, Validation Accuracy: 0.6353
# Epoch [38/70], Train Loss: 0.1065, Train Accuracy: 0.9949, Validation Loss: 0.7683, Validation Accuracy: 0.6353
# Epoch [39/70], Train Loss: 0.0908, Train Accuracy: 0.9983, Validation Loss: 0.8046, Validation Accuracy: 0.6529
# Epoch [40/70], Train Loss: 0.0751, Train Accuracy: 1.0000, Validation Loss: 0.8301, Validation Accuracy: 0.6529
# Epoch [41/70], Train Loss: 0.0657, Train Accuracy: 1.0000, Validation Loss: 0.8657, Validation Accuracy: 0.6471
# Epoch [42/70], Train Loss: 0.0567, Train Accuracy: 1.0000, Validation Loss: 0.9241, Validation Accuracy: 0.6529
# Epoch [43/70], Train Loss: 0.0540, Train Accuracy: 1.0000, Validation Loss: 1.0057, Validation Accuracy: 0.5882
# Epoch [44/70], Train Loss: 0.0609, Train Accuracy: 0.9949, Validation Loss: 0.9597, Validation Accuracy: 0.6353
# Epoch [45/70], Train Loss: 0.0450, Train Accuracy: 1.0000, Validation Loss: 1.0036, Validation Accuracy: 0.6176
# Early stopping triggered.
# Bestloss
# Accuracy: 0.5465
# Sensitivity: 0.4783
# Specificity: 0.6250
# Positive Predictive Value: 0.5946
# Negative Predictive Value: 0.5102
#
# Bestacc
# Accuracy: 0.5465
# Sensitivity: 0.4783
# Specificity: 0.6250
# Positive Predictive Value: 0.5946
# Negative Predictive Value: 0.5102

# %% [markdown]
# # Ho

# %%
class SimpleCNN_ho(nn.Module):
    def __init__(self):
        super(SimpleCNN_ho, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)

        self.channel_attention2 = ChannelAttention(32)
    
        # self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        x = self.channel_attention2(x)
        # x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
#aal
# 定义超参数

input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_ho()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
# 初始化
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None

# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(ho)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(ho)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_ho_notmodify_attention_channel.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_ho_notmodify_attention_channel.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 0.7123, Train Accuracy: 0.5143, Validation Loss: 0.6947, Validation Accuracy: 0.5353
# Epoch [2/50], Train Loss: 0.6909, Train Accuracy: 0.5396, Validation Loss: 0.6927, Validation Accuracy: 0.5588
# Epoch [3/50], Train Loss: 0.6904, Train Accuracy: 0.6003, Validation Loss: 0.6907, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6839, Train Accuracy: 0.5464, Validation Loss: 0.6896, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6744, Train Accuracy: 0.5481, Validation Loss: 0.6858, Validation Accuracy: 0.5412
# Epoch [6/50], Train Loss: 0.6599, Train Accuracy: 0.6239, Validation Loss: 0.6825, Validation Accuracy: 0.5471
# Epoch [7/50], Train Loss: 0.6336, Train Accuracy: 0.6509, Validation Loss: 0.6805, Validation Accuracy: 0.5706
# Epoch [8/50], Train Loss: 0.6040, Train Accuracy: 0.7133, Validation Loss: 0.7291, Validation Accuracy: 0.5235
# Epoch [9/50], Train Loss: 0.5947, Train Accuracy: 0.6661, Validation Loss: 0.7086, Validation Accuracy: 0.5412
# Epoch [10/50], Train Loss: 0.5844, Train Accuracy: 0.6847, Validation Loss: 0.6939, Validation Accuracy: 0.5647
# Epoch [11/50], Train Loss: 0.5700, Train Accuracy: 0.6981, Validation Loss: 0.6854, Validation Accuracy: 0.5824
# Epoch [12/50], Train Loss: 0.5580, Train Accuracy: 0.6948, Validation Loss: 0.6785, Validation Accuracy: 0.5882
# Epoch [13/50], Train Loss: 0.5278, Train Accuracy: 0.7673, Validation Loss: 0.7282, Validation Accuracy: 0.5529
# Epoch [14/50], Train Loss: 0.4869, Train Accuracy: 0.7960, Validation Loss: 0.6924, Validation Accuracy: 0.5882
# Epoch [15/50], Train Loss: 0.4387, Train Accuracy: 0.8263, Validation Loss: 0.7299, Validation Accuracy: 0.5941
# Epoch [16/50], Train Loss: 0.4022, Train Accuracy: 0.8634, Validation Loss: 0.7136, Validation Accuracy: 0.6176
# Epoch [17/50], Train Loss: 0.4285, Train Accuracy: 0.7841, Validation Loss: 0.7997, Validation Accuracy: 0.5647
# Epoch [18/50], Train Loss: 0.3945, Train Accuracy: 0.8162, Validation Loss: 0.9016, Validation Accuracy: 0.5647
# Epoch [19/50], Train Loss: 0.4107, Train Accuracy: 0.8027, Validation Loss: 0.7051, Validation Accuracy: 0.6118
# Epoch [20/50], Train Loss: 0.3536, Train Accuracy: 0.8668, Validation Loss: 0.7013, Validation Accuracy: 0.6176
# Epoch [21/50], Train Loss: 0.3006, Train Accuracy: 0.9191, Validation Loss: 0.7979, Validation Accuracy: 0.5647
# Epoch [22/50], Train Loss: 0.2644, Train Accuracy: 0.9207, Validation Loss: 0.7749, Validation Accuracy: 0.6059
# Epoch [23/50], Train Loss: 0.2283, Train Accuracy: 0.9410, Validation Loss: 0.8414, Validation Accuracy: 0.5882
# Epoch [24/50], Train Loss: 0.2160, Train Accuracy: 0.9410, Validation Loss: 0.8376, Validation Accuracy: 0.6176
# Epoch [25/50], Train Loss: 0.2014, Train Accuracy: 0.9309, Validation Loss: 0.9390, Validation Accuracy: 0.5706
# Epoch [26/50], Train Loss: 0.1987, Train Accuracy: 0.9444, Validation Loss: 0.7856, Validation Accuracy: 0.6294
# Epoch [27/50], Train Loss: 0.1402, Train Accuracy: 0.9798, Validation Loss: 0.7874, Validation Accuracy: 0.6294
# Epoch [28/50], Train Loss: 0.1182, Train Accuracy: 0.9899, Validation Loss: 0.8110, Validation Accuracy: 0.6294
# Epoch [29/50], Train Loss: 0.0991, Train Accuracy: 0.9933, Validation Loss: 0.8461, Validation Accuracy: 0.6471
# Epoch [30/50], Train Loss: 0.0932, Train Accuracy: 0.9916, Validation Loss: 0.8890, Validation Accuracy: 0.6118
# Epoch [31/50], Train Loss: 0.0921, Train Accuracy: 0.9848, Validation Loss: 1.0311, Validation Accuracy: 0.6235
# Epoch [32/50], Train Loss: 0.1014, Train Accuracy: 0.9713, Validation Loss: 0.9823, Validation Accuracy: 0.6118
# Epoch [33/50], Train Loss: 0.0875, Train Accuracy: 0.9848, Validation Loss: 0.9645, Validation Accuracy: 0.6000
# Epoch [34/50], Train Loss: 0.0566, Train Accuracy: 1.0000, Validation Loss: 0.9682, Validation Accuracy: 0.6059
# Epoch [35/50], Train Loss: 0.0450, Train Accuracy: 0.9983, Validation Loss: 0.9826, Validation Accuracy: 0.6176
# Epoch [36/50], Train Loss: 0.0316, Train Accuracy: 1.0000, Validation Loss: 1.1119, Validation Accuracy: 0.6235
# Epoch [37/50], Train Loss: 0.0276, Train Accuracy: 1.0000, Validation Loss: 1.0930, Validation Accuracy: 0.6471
# Epoch [38/50], Train Loss: 0.0209, Train Accuracy: 1.0000, Validation Loss: 1.1208, Validation Accuracy: 0.6059
# Epoch [39/50], Train Loss: 0.0159, Train Accuracy: 1.0000, Validation Loss: 1.1674, Validation Accuracy: 0.6059
# Early stopping triggered.
# Bestloss
# Accuracy: 0.6395
# Sensitivity: 0.6957
# Specificity: 0.5750
# Positive Predictive Value: 0.6531
# Negative Predictive Value: 0.6216
#
# Bestacc
# Accuracy: 0.4651
# Sensitivity: 0.2826
# Specificity: 0.6750
# Positive Predictive Value: 0.5000
# Negative Predictive Value: 0.4500

# %% [markdown]
# # ez

# %%
class SimpleCNN_ez(nn.Module):
    def __init__(self):
        super(SimpleCNN_ez, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)

        self.channel_attention2 = ChannelAttention(32)
    
        # self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        x = self.channel_attention2(x)
        # x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# 定义超参数
input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_ez()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None
# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(ez)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(ez)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and acc_count >= acc_patience:
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_ez_notmodify_attention_channel.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_ez_notmodify_attention_channel.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 0.7594, Train Accuracy: 0.4789, Validation Loss: 0.6948, Validation Accuracy: 0.5353
# Epoch [2/50], Train Loss: 0.7014, Train Accuracy: 0.5346, Validation Loss: 0.6942, Validation Accuracy: 0.5353
# Epoch [3/50], Train Loss: 0.6888, Train Accuracy: 0.5346, Validation Loss: 0.6902, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6888, Train Accuracy: 0.5346, Validation Loss: 0.6899, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6874, Train Accuracy: 0.5346, Validation Loss: 0.6893, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6843, Train Accuracy: 0.5363, Validation Loss: 0.6885, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6792, Train Accuracy: 0.5396, Validation Loss: 0.6870, Validation Accuracy: 0.5412
# Epoch [8/50], Train Loss: 0.6669, Train Accuracy: 0.5835, Validation Loss: 0.6844, Validation Accuracy: 0.5353
# Epoch [9/50], Train Loss: 0.6498, Train Accuracy: 0.6492, Validation Loss: 0.6867, Validation Accuracy: 0.5588
# Epoch [10/50], Train Loss: 0.6238, Train Accuracy: 0.6695, Validation Loss: 0.6885, Validation Accuracy: 0.5353
# Epoch [11/50], Train Loss: 0.5965, Train Accuracy: 0.6914, Validation Loss: 0.6917, Validation Accuracy: 0.5882
# Epoch [12/50], Train Loss: 0.5749, Train Accuracy: 0.7167, Validation Loss: 0.7350, Validation Accuracy: 0.5294
# Epoch [13/50], Train Loss: 0.5823, Train Accuracy: 0.6745, Validation Loss: 0.7464, Validation Accuracy: 0.5353
# Epoch [14/50], Train Loss: 0.5706, Train Accuracy: 0.7133, Validation Loss: 0.6862, Validation Accuracy: 0.5647
# Epoch [15/50], Train Loss: 0.5207, Train Accuracy: 0.7639, Validation Loss: 0.6834, Validation Accuracy: 0.5706
# Epoch [16/50], Train Loss: 0.5023, Train Accuracy: 0.7909, Validation Loss: 0.6953, Validation Accuracy: 0.6294
# Epoch [17/50], Train Loss: 0.4816, Train Accuracy: 0.7757, Validation Loss: 0.6947, Validation Accuracy: 0.6118
# Epoch [18/50], Train Loss: 0.4538, Train Accuracy: 0.8010, Validation Loss: 0.7366, Validation Accuracy: 0.5588
# Epoch [19/50], Train Loss: 0.4523, Train Accuracy: 0.7960, Validation Loss: 0.7471, Validation Accuracy: 0.5824
# Epoch [20/50], Train Loss: 0.4215, Train Accuracy: 0.8229, Validation Loss: 0.7685, Validation Accuracy: 0.5824
# Epoch [21/50], Train Loss: 0.3878, Train Accuracy: 0.8550, Validation Loss: 0.7497, Validation Accuracy: 0.5588
# Epoch [22/50], Train Loss: 0.3543, Train Accuracy: 0.8668, Validation Loss: 0.7285, Validation Accuracy: 0.6235
# Epoch [23/50], Train Loss: 0.3063, Train Accuracy: 0.9005, Validation Loss: 0.7535, Validation Accuracy: 0.5706
# Epoch [24/50], Train Loss: 0.2649, Train Accuracy: 0.9258, Validation Loss: 0.7881, Validation Accuracy: 0.5529
# Epoch [25/50], Train Loss: 0.2318, Train Accuracy: 0.9511, Validation Loss: 0.8193, Validation Accuracy: 0.5588
# Epoch [26/50], Train Loss: 0.2526, Train Accuracy: 0.9056, Validation Loss: 0.9468, Validation Accuracy: 0.5941
# Early stopping triggered.
# Bestloss
# Accuracy: 0.4302
# Sensitivity: 0.0000
# Specificity: 0.9250
# Positive Predictive Value: 0.0000
# Negative Predictive Value: 0.4458
#
# Bestacc
# Accuracy: 0.5581
# Sensitivity: 0.4130
# Specificity: 0.7250
# Positive Predictive Value: 0.6333
# Negative Predictive Value: 0.5179

# %% [markdown]
# # csv

# %%
class SimpleCNN_csv(nn.Module):
    def __init__(self):
        super(SimpleCNN_csv, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)
        self.fc2 = nn.Linear(128, 2)

        self.channel_attention2 = ChannelAttention(32)
    
        # self.spatial_attention2 = SpatialAttention()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        
        # Apply channel attention and spatial attention after conv2
        x = self.channel_attention2(x)
        # x = self.spatial_attention2(x)

        x = self.pool(x)
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# 定义超参数
input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_csv()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None
# =====================
# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(csv)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(csv)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and (acc_count >= acc_patience and epoch > 30):
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_csv_notmodify_attention_channel.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_csv_notmodify_attention_channel.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

model_save_path = "pth/model_csv_notmodify_attention.pth"
torch.save(model.state_dict(), model_save_path)
# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 1.1578, Train Accuracy: 0.4890, Validation Loss: 0.7647, Validation Accuracy: 0.4647
# Epoch [2/50], Train Loss: 0.7221, Train Accuracy: 0.5025, Validation Loss: 0.7188, Validation Accuracy: 0.5353
# Epoch [3/50], Train Loss: 0.6989, Train Accuracy: 0.5346, Validation Loss: 0.6904, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6901, Train Accuracy: 0.5346, Validation Loss: 0.6919, Validation Accuracy: 0.5294
# Epoch [5/50], Train Loss: 0.6891, Train Accuracy: 0.5346, Validation Loss: 0.6901, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6849, Train Accuracy: 0.5346, Validation Loss: 0.6886, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6805, Train Accuracy: 0.5346, Validation Loss: 0.6877, Validation Accuracy: 0.5353
# Epoch [8/50], Train Loss: 0.6787, Train Accuracy: 0.5346, Validation Loss: 0.6858, Validation Accuracy: 0.5353
# Epoch [9/50], Train Loss: 0.6748, Train Accuracy: 0.6121, Validation Loss: 0.6857, Validation Accuracy: 0.5824
# Epoch [10/50], Train Loss: 0.6681, Train Accuracy: 0.6762, Validation Loss: 0.6825, Validation Accuracy: 0.5529
# Epoch [11/50], Train Loss: 0.6591, Train Accuracy: 0.5750, Validation Loss: 0.6793, Validation Accuracy: 0.5647
# Epoch [12/50], Train Loss: 0.6487, Train Accuracy: 0.6914, Validation Loss: 0.6754, Validation Accuracy: 0.5647
# Epoch [13/50], Train Loss: 0.6346, Train Accuracy: 0.6442, Validation Loss: 0.6730, Validation Accuracy: 0.5647
# Epoch [14/50], Train Loss: 0.6179, Train Accuracy: 0.7285, Validation Loss: 0.6692, Validation Accuracy: 0.5706
# Epoch [15/50], Train Loss: 0.6061, Train Accuracy: 0.6998, Validation Loss: 0.6684, Validation Accuracy: 0.5706
# Epoch [16/50], Train Loss: 0.5801, Train Accuracy: 0.7538, Validation Loss: 0.6693, Validation Accuracy: 0.5412
# Epoch [17/50], Train Loss: 0.5585, Train Accuracy: 0.7555, Validation Loss: 0.6679, Validation Accuracy: 0.5882
# Epoch [18/50], Train Loss: 0.5453, Train Accuracy: 0.7420, Validation Loss: 0.6720, Validation Accuracy: 0.5529
# Epoch [19/50], Train Loss: 0.5283, Train Accuracy: 0.7622, Validation Loss: 0.7238, Validation Accuracy: 0.5588
# Epoch [20/50], Train Loss: 0.5008, Train Accuracy: 0.7841, Validation Loss: 0.6754, Validation Accuracy: 0.5941
# Epoch [21/50], Train Loss: 0.4833, Train Accuracy: 0.7858, Validation Loss: 0.6916, Validation Accuracy: 0.5941
# Epoch [22/50], Train Loss: 0.4665, Train Accuracy: 0.8044, Validation Loss: 0.6789, Validation Accuracy: 0.5588
# Epoch [23/50], Train Loss: 0.4354, Train Accuracy: 0.8314, Validation Loss: 0.7254, Validation Accuracy: 0.5824
# Epoch [24/50], Train Loss: 0.4158, Train Accuracy: 0.8280, Validation Loss: 0.6649, Validation Accuracy: 0.5941
# Epoch [25/50], Train Loss: 0.4029, Train Accuracy: 0.8415, Validation Loss: 0.7133, Validation Accuracy: 0.5941
# Epoch [26/50], Train Loss: 0.3609, Train Accuracy: 0.8786, Validation Loss: 0.6668, Validation Accuracy: 0.6059
# Epoch [27/50], Train Loss: 0.3172, Train Accuracy: 0.9207, Validation Loss: 0.7406, Validation Accuracy: 0.6000
# Epoch [28/50], Train Loss: 0.3021, Train Accuracy: 0.9106, Validation Loss: 0.7341, Validation Accuracy: 0.6118
# Epoch [29/50], Train Loss: 0.2870, Train Accuracy: 0.9106, Validation Loss: 0.7672, Validation Accuracy: 0.6118
# Epoch [30/50], Train Loss: 0.2692, Train Accuracy: 0.9140, Validation Loss: 0.6883, Validation Accuracy: 0.5882
# Epoch [31/50], Train Loss: 0.2328, Train Accuracy: 0.9494, Validation Loss: 0.7251, Validation Accuracy: 0.5882
# Epoch [32/50], Train Loss: 0.1974, Train Accuracy: 0.9663, Validation Loss: 0.7060, Validation Accuracy: 0.6118
# Epoch [33/50], Train Loss: 0.1608, Train Accuracy: 0.9899, Validation Loss: 0.7090, Validation Accuracy: 0.6294
# Epoch [34/50], Train Loss: 0.1556, Train Accuracy: 0.9764, Validation Loss: 0.7516, Validation Accuracy: 0.5882
# Epoch [35/50], Train Loss: 0.1163, Train Accuracy: 0.9966, Validation Loss: 0.7553, Validation Accuracy: 0.5765
# Epoch [36/50], Train Loss: 0.0954, Train Accuracy: 1.0000, Validation Loss: 0.7611, Validation Accuracy: 0.6294
# Epoch [37/50], Train Loss: 0.0775, Train Accuracy: 0.9983, Validation Loss: 0.7809, Validation Accuracy: 0.6059
# Epoch [38/50], Train Loss: 0.0632, Train Accuracy: 1.0000, Validation Loss: 0.8240, Validation Accuracy: 0.6000
# Epoch [39/50], Train Loss: 0.0521, Train Accuracy: 1.0000, Validation Loss: 0.8383, Validation Accuracy: 0.6059
# Epoch [40/50], Train Loss: 0.0454, Train Accuracy: 1.0000, Validation Loss: 0.8708, Validation Accuracy: 0.6000
# Epoch [41/50], Train Loss: 0.0366, Train Accuracy: 1.0000, Validation Loss: 0.8994, Validation Accuracy: 0.6294
# Epoch [42/50], Train Loss: 0.0317, Train Accuracy: 1.0000, Validation Loss: 0.9142, Validation Accuracy: 0.6059
# Epoch [43/50], Train Loss: 0.0283, Train Accuracy: 1.0000, Validation Loss: 0.9270, Validation Accuracy: 0.6059
# Early stopping triggered.
# Bestloss
# Accuracy: 0.5465
# Sensitivity: 0.3913
# Specificity: 0.7250
# Positive Predictive Value: 0.6207
# Negative Predictive Value: 0.5088
#
# Bestacc
# Accuracy: 0.6279
# Sensitivity: 0.6957
# Specificity: 0.5500
# Positive Predictive Value: 0.6400
# Negative Predictive Value: 0.6111

# %%
# 定义超参数
input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 50
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN_csv()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(ho_train_dir,aal_train_dir,ez_train_dir,csv_train_dir, transform=None)
valid_dataset = MultiModalDataset(ho_valid_dir,aal_valid_dir,ez_valid_dir,csv_valid_dir, transform=None)
test_dataset = MultiModalDataset(ho_test_dir,aal_test_dir,ez_test_dir,csv_test_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
best_val_loss = float('inf')
best_val_acc = 0.0
loss_patience = 10
acc_patience = 10
loss_count = 0
acc_count = 0
model_bestloss = None
model_bestacc = None
# =====================
# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (ho,aal,ez,csv,label) in enumerate(train_loader):
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
        optimizer.zero_grad()
        outputs = model(csv)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * csv.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for ho,aal,ez,csv,label in valid_loader:
            ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device),csv.to(device),label.to(device)
            outputs = model(csv)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * csv.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")

    # 保存模型
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        model_bestloss = copy.deepcopy(model)
        loss_count = 0
    else:
        loss_count += 1

    if valid_acc > best_val_acc:
        best_val_acc = valid_acc
        model_bestacc = copy.deepcopy(model)
        acc_count = 0
    else:
        acc_count += 1

    # 如果损失连续增加，且准确率不再增加，则停止训练
    if loss_count >= loss_patience and (acc_count >= acc_patience and epoch > 30):
        print("Early stopping triggered.")
        break

# 保存最佳模型
torch.save(model_bestacc.state_dict(), 'pth/accmodel_csv_notmodify_attention_channel.pth')
torch.save(model_bestloss.state_dict(), 'pth/lossmodel_csv_notmodify_attention_channel.pth')

# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()

model_save_path = "pth/model_csv_notmodify_attention.pth"
torch.save(model.state_dict(), model_save_path)
# 在测试阶段，我们需要跟踪的指标
TP = 0
TN = 0
FP = 0
FN = 0
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# 开始测试
print('Bestloss')
model_bestloss.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(ho)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")

print('\nBestacc')
TP = 0
TN = 0
FP = 0
FN = 0
model_bestacc.eval()
with torch.no_grad():
    for ho, aal, ez, csv, label in test_loader:
        ho, aal, ez, csv, labels = ho.to(device), aal.to(device), ez.to(device), csv.to(device), label.to(device)
        outputs = model(aal)
        _, predicted = torch.max(outputs.data, 1)

        for i in range(len(labels)):
            true_label = labels[i]
            pred_label = predicted[i]
            if true_label == 1 and pred_label == 1:
                TP += 1
            elif true_label == 0 and pred_label == 0:
                TN += 1
            elif true_label == 0 and pred_label == 1:
                FP += 1
            elif true_label == 1 and pred_label == 0:
                FN += 1

# 计算各项指标
accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)

print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Positive Predictive Value: {ppv:.4f}")
print(f"Negative Predictive Value: {npv:.4f}")
# Out:
# 训练
# Epoch [1/50], Train Loss: 0.7981, Train Accuracy: 0.4722, Validation Loss: 0.6970, Validation Accuracy: 0.4647
# Epoch [2/50], Train Loss: 0.6922, Train Accuracy: 0.5110, Validation Loss: 0.6944, Validation Accuracy: 0.5353
# Epoch [3/50], Train Loss: 0.6898, Train Accuracy: 0.5346, Validation Loss: 0.6901, Validation Accuracy: 0.5353
# Epoch [4/50], Train Loss: 0.6839, Train Accuracy: 0.5481, Validation Loss: 0.6889, Validation Accuracy: 0.5353
# Epoch [5/50], Train Loss: 0.6814, Train Accuracy: 0.5346, Validation Loss: 0.6868, Validation Accuracy: 0.5353
# Epoch [6/50], Train Loss: 0.6728, Train Accuracy: 0.5464, Validation Loss: 0.6851, Validation Accuracy: 0.5353
# Epoch [7/50], Train Loss: 0.6646, Train Accuracy: 0.6020, Validation Loss: 0.6846, Validation Accuracy: 0.5471
# Epoch [8/50], Train Loss: 0.6492, Train Accuracy: 0.6020, Validation Loss: 0.6831, Validation Accuracy: 0.5588
# Epoch [9/50], Train Loss: 0.6308, Train Accuracy: 0.6981, Validation Loss: 0.6785, Validation Accuracy: 0.5353
# Epoch [10/50], Train Loss: 0.5982, Train Accuracy: 0.7336, Validation Loss: 0.6774, Validation Accuracy: 0.5588
# Epoch [11/50], Train Loss: 0.5746, Train Accuracy: 0.7386, Validation Loss: 0.6790, Validation Accuracy: 0.5588
# Epoch [12/50], Train Loss: 0.5305, Train Accuracy: 0.7487, Validation Loss: 0.6754, Validation Accuracy: 0.5706
# Epoch [13/50], Train Loss: 0.5108, Train Accuracy: 0.7656, Validation Loss: 0.6723, Validation Accuracy: 0.5882
# Epoch [14/50], Train Loss: 0.4609, Train Accuracy: 0.8179, Validation Loss: 0.7022, Validation Accuracy: 0.5941
# Epoch [15/50], Train Loss: 0.4804, Train Accuracy: 0.7656, Validation Loss: 0.7942, Validation Accuracy: 0.5529
# Epoch [16/50], Train Loss: 0.4707, Train Accuracy: 0.7504, Validation Loss: 0.6976, Validation Accuracy: 0.5824
# Epoch [17/50], Train Loss: 0.4179, Train Accuracy: 0.8432, Validation Loss: 0.7248, Validation Accuracy: 0.5824
# Epoch [18/50], Train Loss: 0.3805, Train Accuracy: 0.8567, Validation Loss: 0.6693, Validation Accuracy: 0.6529
# Epoch [19/50], Train Loss: 0.3397, Train Accuracy: 0.8921, Validation Loss: 0.7027, Validation Accuracy: 0.6176
# Epoch [20/50], Train Loss: 0.3184, Train Accuracy: 0.8887, Validation Loss: 0.7076, Validation Accuracy: 0.6000
# Epoch [21/50], Train Loss: 0.2639, Train Accuracy: 0.9275, Validation Loss: 0.7131, Validation Accuracy: 0.5941
# Epoch [22/50], Train Loss: 0.2358, Train Accuracy: 0.9511, Validation Loss: 0.9071, Validation Accuracy: 0.6059
# Epoch [23/50], Train Loss: 0.2577, Train Accuracy: 0.8988, Validation Loss: 0.8569, Validation Accuracy: 0.6176
# Epoch [24/50], Train Loss: 0.2085, Train Accuracy: 0.9444, Validation Loss: 0.8417, Validation Accuracy: 0.6235
# Epoch [25/50], Train Loss: 0.1914, Train Accuracy: 0.9494, Validation Loss: 0.8534, Validation Accuracy: 0.6235
# Epoch [26/50], Train Loss: 0.1543, Train Accuracy: 0.9680, Validation Loss: 0.7863, Validation Accuracy: 0.6353
# Epoch [27/50], Train Loss: 0.1092, Train Accuracy: 0.9966, Validation Loss: 0.7891, Validation Accuracy: 0.6059
# Epoch [28/50], Train Loss: 0.0834, Train Accuracy: 0.9966, Validation Loss: 0.8265, Validation Accuracy: 0.6000
# Epoch [29/50], Train Loss: 0.0624, Train Accuracy: 1.0000, Validation Loss: 0.8650, Validation Accuracy: 0.6000
# Epoch [30/50], Train Loss: 0.0479, Train Accuracy: 1.0000, Validation Loss: 0.9303, Validation Accuracy: 0.6118
# Epoch [31/50], Train Loss: 0.0390, Train Accuracy: 1.0000, Validation Loss: 1.0219, Validation Accuracy: 0.6353
# Epoch [32/50], Train Loss: 0.0448, Train Accuracy: 1.0000, Validation Loss: 1.0245, Validation Accuracy: 0.6059
# Early stopping triggered.
# Bestloss
# Accuracy: 0.4767
# Sensitivity: 0.1522
# Specificity: 0.8500
# Positive Predictive Value: 0.5385
# Negative Predictive Value: 0.4658
#
# Bestacc
# Accuracy: 0.5116
# Sensitivity: 0.3913
# Specificity: 0.6500
# Positive Predictive Value: 0.5625
# Negative Predictive Value: 0.4815
