# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
  ! gdown --id '1Zw9kScYqS_HtCop3s-MgbniUeECoyndI' --output ABIDE_alff.zip
  # !unzip "/content/ABIDE_alff.zip"
  ! gdown --id '1rGLM-WsiwCsAqJowzq9X5ltKtImhAkoG' --output ABIDE_csv.zip
  # !unzip "/content/ABIDE_csv.zip"
# Out:
# Mon May  1 11:50:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Zw9kScYqS_HtCop3s-MgbniUeECoyndI
# To: /content/ABIDE_alff.zip
# 100% 507M/507M [00:02<00:00, 197MB/s]
# Archive:  /content/ABIDE_alff.zip
#    creating: alff_split_1/
#    creating: alff_split_1/valid/
#    creating: alff_split_1/test/
#    creating: alff_split_1/train/
#    creating: alff_split_1/valid/ASD/
#    creating: alff_split_1/valid/TD/
#    creating: alff_split_1/test/ASD/
#    creating: alff_split_1/test/TD/
#    creating: alff_split_1/train/ASD/
#    creating: alff_split_1/train/TD/
#   inflating: alff_split_1/valid/ASD/Leuven_2_0050752.nii.gz
#   inflating: alff_split_1/valid/ASD/UM_2_0050407.nii.gz
#   inflating: alff_split_1/valid/ASD/USM_0050500.nii.gz
#   inflating: alff_split_1/valid/ASD/MaxMun_b_0051324.nii.gz
#   inflating: alff_split_1/valid/ASD/Stanford_0051179.nii.gz
#   inflating: alff_split_1/valid/ASD/USM_0050490.nii.gz
#   inflating: alff_split_1/valid/ASD/KKI_0050798.nii.gz
#   inflating: alff_split_1/valid/ASD/UCLA_2_0051302.nii.gz
#   inflating: alff_split_1/valid/ASD/USM_0050482.nii.gz
#   inflating: alff_split_1/valid/ASD/Pitt_0050023.nii.gz
#   inflating: alff_split_1/valid/ASD/Pitt_0050009.nii.gz
#   inflating: alff_split_1/valid/ASD/Caltech_0051458.nii.gz
#   inflating: alff_split_1/valid/ASD/Pitt_0050005.nii.gz
#   inflating: alff_split_1/valid/ASD/Olin_0050122.nii.gz
#   inflating: alff_split_1/valid/ASD/Caltech_0051470.nii.gz
#   inflating: alff_split_1/valid/ASD/Olin_0050118.nii.gz
#   inflating: alff_split_1/valid/ASD/MaxMun_b_0051326.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0050992.nii.gz
#   inflating: alff_split_1/valid/ASD/Yale_0050617.nii.gz
#   inflating: alff_split_1/valid/ASD/Leuven_1_0050693.nii.gz
#   inflating: alff_split_1/valid/ASD/Stanford_0051165.nii.gz
#   inflating: alff_split_1/valid/ASD/OHSU_0050142.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0050965.nii.gz
#   inflating: alff_split_1/valid/ASD/UCLA_1_0051249.nii.gz
#   inflating: alff_split_1/valid/ASD/Leuven_1_0050697.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0051035.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0051003.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0051011.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0051029.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0051025.nii.gz
#   inflating: alff_split_1/valid/ASD/Yale_0050603.nii.gz
#   inflating: alff_split_1/valid/ASD/UCLA_1_0051224.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0050986.nii.gz
#   inflating: alff_split_1/valid/ASD/UCLA_1_0051212.nii.gz
#   inflating: alff_split_1/valid/ASD/Yale_0050627.nii.gz
#   inflating: alff_split_1/valid/ASD/SDSU_0050186.nii.gz
#   inflating: alff_split_1/valid/ASD/Trinity_0050250.nii.gz
#   inflating: alff_split_1/valid/ASD/USM_0050494.nii.gz
#   inflating: alff_split_1/valid/ASD/SBL_0051576.nii.gz
#   inflating: alff_split_1/valid/ASD/UM_1_0050275.nii.gz
#   inflating: alff_split_1/valid/ASD/OHSU_0050145.nii.gz
#   inflating: alff_split_1/valid/ASD/OHSU_0050149.nii.gz
#   inflating: alff_split_1/valid/ASD/UM_1_0050298.nii.gz
#   inflating: alff_split_1/valid/ASD/USM_0050525.nii.gz
#   inflating: alff_split_1/valid/ASD/CMU_a_0050649.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0050983.nii.gz
#   inflating: alff_split_1/valid/ASD/UCLA_1_0051240.nii.gz
#   inflating: alff_split_1/valid/ASD/KKI_0050824.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0051014.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0050981.nii.gz
#   inflating: alff_split_1/valid/ASD/UCLA_2_0051291.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0051006.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0050993.nii.gz
#   inflating: alff_split_1/valid/ASD/Yale_0050620.nii.gz
#   inflating: alff_split_1/valid/ASD/Leuven_1_0050702.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0050972.nii.gz
#   inflating: alff_split_1/valid/ASD/Leuven_2_0050755.nii.gz
#   inflating: alff_split_1/valid/ASD/NYU_0050997.nii.gz
#   inflating: alff_split_1/valid/ASD/USM_0050507.nii.gz
#   inflating: alff_split_1/valid/ASD/MaxMun_b_0051323.nii.gz
#   inflating: alff_split_1/valid/ASD/Stanford_0051160.nii.gz
#   inflating: alff_split_1/valid/ASD/UM_1_0050280.nii.gz
#   inflating: alff_split_1/valid/ASD/Leuven
nii.gz
#   inflating: alff_split_1/valid/TD/UM_1_0050330.nii.gz
#   inflating: alff_split_1/valid/TD/UCLA_2_0051313.nii.gz
#   inflating: alff_split_1/valid/TD/Yale_0050576.nii.gz
#   inflating: alff_split_1/valid/TD/Yale_0050568.nii.gz
#   inflating: alff_split_1/valid/TD/NYU_0051102.nii.gz
#   inflating: alff_split_1/valid/TD/NYU_0051049.nii.gz
#   inflating: alff_split_1/valid/TD/Yale_0050572.nii.gz
#   inflating: alff_split_1/valid/TD/UM_1_0050345.nii.gz
#   inflating: alff_split_1/valid/TD/Trinity_0051135.nii.gz
#   inflating: alff_split_1/valid/TD/Yale_0050556.nii.gz
#   inflating: alff_split_1/valid/TD/Leuven_1_0050706.nii.gz
#   inflating: alff_split_1/valid/TD/SDSU_0050204.nii.gz
#   inflating: alff_split_1/valid/TD/Pitt_0050047.nii.gz
#   inflating: alff_split_1/valid/TD/Caltech_0051479.nii.gz
#   inflating: alff_split_1/valid/TD/Trinity_0051137.nii.gz
#   inflating: alff_split_1/valid/TD/Yale_0050562.nii.gz
#   inflating: alff_split_1/valid/TD/Yale_0050570.nii.gz
#   inflating: alff_split_1/valid/TD/SDSU_0050195.nii.gz
#   inflating: alff_split_1/valid/TD/Yale_0050558.nii.gz
#   inflating: alff_split_1/valid/TD/OHSU_0050169.nii.gz
#   inflating: alff_split_1/valid/TD/NYU_0051128.nii.gz
#   inflating: alff_split_1/valid/TD/NYU_0051036.nii.gz
#   inflating: alff_split_1/valid/TD/USM_0050442.nii.gz
#   inflating: alff_split_1/valid/TD/UM_2_0050426.nii.gz
#   inflating: alff_split_1/valid/TD/NYU_0051059.nii.gz
#   inflating: alff_split_1/valid/TD/NYU_0051124.nii.gz
#   inflating: alff_split_1/test/ASD/Stanford_0051167.nii.gz
#   inflating: alff_split_1/test/ASD/USM_0050524.nii.gz
#   inflating: alff_split_1/test/ASD/UM_1_0050295.nii.gz
#   inflating: alff_split_1/test/ASD/SDSU_0050190.nii.gz
#   inflating: alff_split_1/test/ASD/OHSU_0050148.nii.gz
#   inflating: alff_split_1/test/ASD/OHSU_0050156.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0051015.nii.gz
#   inflating: alff_split_1/test/ASD/UCLA_1_0051230.nii.gz
#   inflating: alff_split_1/test/ASD/Caltech_0051466.nii.gz
#   inflating: alff_split_1/test/ASD/Caltech_0051474.nii.gz
#   inflating: alff_split_1/test/ASD/SDSU_0050188.nii.gz
#   inflating: alff_split_1/test/ASD/UM_1_0050293.nii.gz
#   inflating: alff_split_1/test/ASD/Yale_0050625.nii.gz
#   inflating: alff_split_1/test/ASD/UCLA_1_0051236.nii.gz
#   inflating: alff_split_1/test/ASD/UM_1_0050283.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0050998.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0050994.nii.gz
#   inflating: alff_split_1/test/ASD/Leuven_2_0050756.nii.gz
#   inflating: alff_split_1/test/ASD/Olin_0050128.nii.gz
#   inflating: alff_split_1/test/ASD/UM_1_0050325.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0050970.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0050962.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0051020.nii.gz
#   inflating: alff_split_1/test/ASD/Yale_0050614.nii.gz
#   inflating: alff_split_1/test/ASD/Leuven_1_0050690.nii.gz
#   inflating: alff_split_1/test/ASD/UCLA_1_0051205.nii.gz
#   inflating: alff_split_1/test/ASD/Leuven_2_0050753.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0051008.nii.gz
#   inflating: alff_split_1/test/ASD/Yale_0050616.nii.gz
#   inflating: alff_split_1/test/ASD/Stanford_0051168.nii.gz
#   inflating: alff_split_1/test/ASD/UM_1_0050284.nii.gz
#   inflating: alff_split_1/test/ASD/UCLA_1_0051239.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0050968.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0050966.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0050978.nii.gz
#   inflating: alff_split_1/test/ASD/Olin_0050129.nii.gz
#   inflating: alff_split_1/test/ASD/Trinity_0050232.nii.gz
#   inflating: alff_split_1/test/ASD/UM_2_0050402.nii.gz
#   inflating: alff_split_1/test/ASD/NYU_0051000.nii.gz
#   inflating: alff_split_1/test/ASD/UCLA_1_0051225.nii.gz
#   inflating: alff_split_1/test/TD/UM_2_0050419.nii.gz
#   inflating: alff_split_1/test/TD/Leuven_2_0050731.nii.gz
#   inflating: alff_split_1/test/TD/UCLA_1_0051279.nii.gz
#   inflating: alff_split_1/test/TD/NYU_0
csv
#   inflating: csv_split_1/train/TD/UCLA_2_0051307.csv
#   inflating: csv_split_1/train/TD/SDSU_0050213.csv
#   inflating: csv_split_1/train/TD/SDSU_0050206.csv
#   inflating: csv_split_1/train/TD/UCLA_2_0051306.csv
#   inflating: csv_split_1/train/TD/UM_1_0050340.csv
#   inflating: csv_split_1/train/TD/USM_0050448.csv
#   inflating: csv_split_1/train/TD/Leuven_1_0050691.csv
#   inflating: csv_split_1/train/TD/Leuven_1_0050685.csv
#   inflating: csv_split_1/train/TD/Yale_0050557.csv
#   inflating: csv_split_1/train/TD/Stanford_0051193.csv
#   inflating: csv_split_1/train/TD/Stanford_0051187.csv
#   inflating: csv_split_1/train/TD/SBL_0051564.csv
#   inflating: csv_split_1/train/TD/Stanford_0051183.csv
#   inflating: csv_split_1/train/TD/Stanford_0051197.csv
#   inflating: csv_split_1/train/TD/SBL_0051570.csv
#   inflating: csv_split_1/train/TD/MaxMun_a_0051365.csv
#   inflating: csv_split_1/train/TD/Yale_0050553.csv
#   inflating: csv_split_1/train/TD/UM_1_0050350.csv
#   inflating: csv_split_1/train/TD/UM_1_0050344.csv
#   inflating: csv_split_1/train/TD/UCLA_2_0051316.csv
#   inflating: csv_split_1/train/TD/MaxMun_c_0051344.csv
#   inflating: csv_split_1/train/TD/MaxMun_d_0051360.csv
#   inflating: csv_split_1/train/TD/MaxMun_c_0051345.csv
#   inflating: csv_split_1/train/TD/SDSU_0050217.csv
#   inflating: csv_split_1/train/TD/SDSU_0050203.csv
#   inflating: csv_split_1/train/TD/Trinity_0050257.csv
#   inflating: csv_split_1/train/TD/UCLA_2_0051303.csv
#   inflating: csv_split_1/train/TD/UM_1_0050351.csv
#   inflating: csv_split_1/train/TD/UM_1_0050379.csv
#   inflating: csv_split_1/train/TD/Yale_0050552.csv
#   inflating: csv_split_1/train/TD/SBL_0051559.csv
#   inflating: csv_split_1/train/TD/MaxMun_a_0051370.csv
#   inflating: csv_split_1/train/TD/Stanford_0051196.csv
#   inflating: csv_split_1/train/TD/Stanford_0051182.csv
#   inflating: csv_split_1/train/TD/Stanford_0051194.csv
#   inflating: csv_split_1/train/TD/Stanford_0051180.csv
#   inflating: csv_split_1/train/TD/Pitt_0050044.csv
#   inflating: csv_split_1/train/TD/UM_1_0050347.csv
#   inflating: csv_split_1/train/TD/UM_1_0050353.csv
#   inflating: csv_split_1/train/TD/UCLA_2_0051315.csv
#   inflating: csv_split_1/train/TD/Trinity_0050269.csv
#   inflating: csv_split_1/train/TD/SDSU_0050215.csv
#   inflating: csv_split_1/train/TD/SDSU_0050201.csv
#   inflating: csv_split_1/train/TD/NYU_0051039.csv
#   inflating: csv_split_1/train/TD/NYU_0051038.csv
#   inflating: csv_split_1/train/TD/SDSU_0050200.csv
#   inflating: csv_split_1/train/TD/SDSU_0050214.csv
#   inflating: csv_split_1/train/TD/UM_1_0050346.csv
#   inflating: csv_split_1/train/TD/USM_0050466.csv
#   inflating: csv_split_1/train/TD/Yale_0050551.csv
#   inflating: csv_split_1/train/TD/Leuven_1_0050683.csv
#   inflating: csv_split_1/train/TD/Stanford_0051181.csv
#   inflating: csv_split_1/train/TD/Olin_0050102.csv
#   inflating: csv_split_1/train/TD/NYU_0051117.csv
#   inflating: csv_split_1/train/TD/UM_2_0050385.csv
#   inflating: csv_split_1/train/TD/Caltech_0051487.csv
#   inflating: csv_split_1/train/TD/Caltech_0051493.csv
#   inflating: csv_split_1/train/TD/Pitt_0050036.csv
#   inflating: csv_split_1/train/TD/OHSU_0050171.csv
#   inflating: csv_split_1/train/TD/UM_1_0050335.csv
#   inflating: csv_split_1/train/TD/KKI_0050774.csv
#   inflating: csv_split_1/train/TD/Trinity_0051139.csv
#   inflating: csv_split_1/train/TD/MaxMun_c_0
csv
#   inflating: csv_split_1/train/TD/UCLA_1_0051252.csv
#   inflating: csv_split_1/train/TD/NYU_0051131.csv
#   inflating: csv_split_1/train/TD/Caltech_0051476.csv
#   inflating: csv_split_1/train/TD/UCLA_1_0051250.csv
#   inflating: csv_split_1/train/TD/KKI_0050787.csv
#   inflating: csv_split_1/train/TD/KKI_0050778.csv
#   inflating: csv_split_1/train/TD/Leuven_2_0050738.csv
#   inflating: csv_split_1/train/TD/KKI_0050817.csv
#   inflating: csv_split_1/train/TD/NYU_0051047.csv
#   inflating: csv_split_1/train/TD/NYU_0051053.csv
#   inflating: csv_split_1/train/TD/MaxMun_c_0051339.csv
#   inflating: csv_split_1/train/TD/NYU_0051084.csv
#   inflating: csv_split_1/train/TD/NYU_0051090.csv
#   inflating: csv_split_1/train/TD/NYU_0051091.csv
#   inflating: csv_split_1/train/TD/NYU_0051085.csv
#   inflating: csv_split_1/train/TD/MaxMun_c_0051338.csv
#   inflating: csv_split_1/train/TD/NYU_0051052.csv
#   inflating: csv_split_1/train/TD/KKI_0050816.csv
#   inflating: csv_split_1/train/TD/Trinity_0051134.csv
#   inflating: csv_split_1/train/TD/Leuven_2_0050739.csv
#   inflating: csv_split_1/train/TD/KKI_0050779.csv
#   inflating: csv_split_1/train/TD/UM_1_0050338.csv
#   inflating: csv_split_1/train/TD/OHSU_0050168.csv
#   inflating: csv_split_1/train/TD/KKI_0050786.csv
#   inflating: csv_split_1/train/TD/UCLA_1_0051251.csv
#   inflating: csv_split_1/train/TD/UM_2_0050388.csv
#   inflating: csv_split_1/train/TD/NYU_0051126.csv
#   inflating: csv_split_1/train/TD/Stanford_0051198.csv
#   inflating: csv_split_1/train/TD/SBL_0051557.csv
#   inflating: csv_split_1/train/TD/NYU_0051155.csv
#   inflating: csv_split_1/train/TD/UM_1_0050363.csv
#   inflating: csv_split_1/train/TD/UM_1_0050377.csv
#   inflating: csv_split_1/train/TD/USM_0050443.csv
#   inflating: csv_split_1/train/TD/Trinity_0050259.csv
#   inflating: csv_split_1/train/TD/Leuven_1_0050710.csv
#   inflating: csv_split_1/train/TD/Trinity_0050264.csv
#   inflating: csv_split_1/train/TD/UM_1_0050362.csv
#   inflating: csv_split_1/train/TD/Yale_0050561.csv
#   inflating: csv_split_1/train/TD/Yale_0050575.csv
#   inflating: csv_split_1/train/TD/Stanford_0051199.csv
#   inflating: csv_split_1/train/TD/MaxMun_a_0051369.csv
#   inflating: csv_split_1/train/TD/NYU_0051156.csv
#   inflating: csv_split_1/train/TD/Yale_0050577.csv
#   inflating: csv_split_1/train/TD/UM_1_0050374.csv
#   inflating: csv_split_1/train/TD/USM_0050468.csv
#   inflating: csv_split_1/train/TD/UM_1_0050348.csv
#   inflating: csv_split_1/train/TD/USM_0050440.csv
#   inflating: csv_split_1/train/TD/Leuven_1_0050707.csv
#   inflating: csv_split_1/train/TD/Trinity_0050267.csv
#   inflating: csv_split_1/train/TD/UM_1_0050349.csv
#   inflating: csv_split_1/train/TD/UM_1_0050375.csv
#   inflating: csv_split_1/train/TD/Leuven_1_0050698.csv
#   inflating: csv_split_1/train/TD/SDSU_0050196.csv
#   inflating: csv_split_1/train/TD/NYU_0051153.csv
#   inflating: csv_split_1/train/TD/Yale_0050566.csv
#   inflating: csv_split_1/train/TD/Leuven_1_0050688.csv
#   inflating: csv_split_1/train/TD/USM_0050445.csv
#   inflating: csv_split_1/train/TD/UM_1_0050365.csv
#   inflating: csv_split_1/train/TD/Trinity_0050263.csv
#   inflating: csv_split_1/train/TD/Trinity_0051141.csv
#   inflating: csv_split_1/train/TD/Trinity_0051140.csv
#   inflating: csv_split_1/train/TD/Trinity_0050262.csv
#   inflating: csv_split_1/train/TD/UM_1_0050364.csv
#   inflating: csv_split_1/train/TD/UM_1_0050370.csv
#   inflating: csv_split_1/train/TD/UM_1_0050358.csv
#   inflating: csv_split_1/train/TD/Yale_0050573.csv
#   inflating: csv_split_1/train/TD/Yale_0050567.csv
#   inflating: csv_split_1/train/TD/NYU_0051152.csv
#   inflating: csv_split_1/train/TD/NYU_0051146.csv
#   inflating: csv_split_1/train/TD/NYU_0051150.csv
#   inflating: csv_split_1/train/TD/Stanford_0051189.csv
#   inflating: csv_split_1/train/TD/Yale_0050559.csv
#   inflating: csv_split_1/train/TD/Pitt_0050059.csv
#   inflating: csv_split_1/train/TD/Yale_0050571.csv
#   inflating: csv_split_1/train/TD/UM_1_0050366.csv
#   inflating: csv_split_1/train/TD/Trinity_0050260.csv
#   inflating: csv_split_1/train/TD/UCLA_2_0051308.csv
#   inflating: csv_split_1/train/TD/Trinity_0051142.csv
#   inflating: csv_split_1/train/TD/SDSU_0050208.csv
#   inflating: csv_split_1/train/TD/Leuven_1_0050701.csv
#   inflating: csv_split_1/train/TD/SDSU_0050209.csv
#   inflating: csv_split_1/train/TD/UCLA_2_0051309.csv
#   inflating: csv_split_1/train/TD/Trinity_0050261.csv
#   inflating: csv_split_1/train/TD/UM_1_0050373.csv
#   inflating: csv_split_1/train/TD/UM_1_0050367.csv
#   inflating: csv_split_1/train/TD/USM_0050447.csv
#   inflating: csv_split_1/train/TD/NYU_0051151.csv

# %%
import numpy as np
import torch
import os
import random
from torch.utils.data import Dataset
import torch.nn.functional as F
import torch.nn as nn
import nibabel as nib

import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from torch.utils.data import ConcatDataset
import torchvision.models as models

# %% [markdown]
# multi-dataset

# %%
random.seed(3407)
rmb_label = {"ASD": 0, "TD": 1}      # 设置标签

class MultiModalDataset(Dataset):
    def __init__(self, data_dirnii , data_dircsv, transform=None):
        """ 
        ABIDE_db的Dataset
        :param data_dir: str, 数据集所在路径
        :param transform: torch.transform，数据预处理
        """
        self.label_name = {"ASD": 0, "TD": 1}
        self.data_infocsv = self.get_csv_info(data_dircsv)  # data_info存储所有txt路径和标签，在DataLoader中通过index读取样本
        self.data_infonii = self.get_nii_info(data_dirnii)  # data_info存储所有txt路径和标签，在DataLoader中通过index读取样本

        self.transform = transform
        random_index = random.randint(0, len(self.data_infonii))
        print(f'Number of samples:[csv:{len(self.data_infocsv)}]  [nii:{len(self.data_infonii)}]')
        print(f'Sample info:[index={random_index}]\n[csv:{self.data_infocsv[random_index]}\n[nii:{self.data_infonii[random_index]}]')

        
    def __getitem__(self, index):
        path_csv, label_csv = self.data_infocsv[index]
        path_nii, label_nii = self.data_infonii[index]
        txt_data = np.loadtxt(path_csv, delimiter=',')
        if label_csv != label_nii:
            print('Error: label not match!')
            print('the error nii:{}\n the error csv:{}',path_nii,path_csv)
        else: label = label_csv
        cor = torch.from_numpy(txt_data).float().unsqueeze(0)
        img = nib.load(path_nii).get_fdata()
        img = torch.tensor(img, dtype=torch.float32).unsqueeze(0)
        
        if self.transform is not None:
            txt = 1   # 在这里做transform，转为tensor等等

        return img,cor, label

    def __len__(self):
        return len(self.data_infocsv)

    @staticmethod
    def get_csv_info(data_dir):
        data_infocsv = list()
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            for sub_dir in dirs:
                txt_names = os.listdir(os.path.join(root, sub_dir))
                txt_names = list(filter(lambda x: x.endswith('.csv'), txt_names))

                # 遍历txt
                for i in range(len(txt_names)):
                    txt_name = txt_names[i]
                    path_txt = os.path.join(root, sub_dir, txt_name)
                    label = rmb_label[sub_dir]
                    data_infocsv.append((path_txt, int(label)))
                    data_infocsv = sorted(data_infocsv)

        return data_infocsv
    
    def get_nii_info(self,data_dir):
        data_infonii = list()
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            for sub_dir in dirs:
                txt_names = os.listdir(os.path.join(root, sub_dir))
                txt_names = list(filter(lambda x: x.endswith('.nii.gz'), txt_names))

                # 遍历txt
                for i in range(len(txt_names)):
                    txt_name = txt_names[i]
                    path_txt = os.path.join(root, sub_dir, txt_name)
                    label = rmb_label[sub_dir]
                    data_infonii.append((path_txt, int(label)))
                    data_infonii = sorted(data_infonii)
        return data_infonii

# %% [markdown]
# # 3D-IMG 特征提取模型
# - 改为特征提取

# %%
import torch
import torch.nn as nn

# 定义 3D 卷积块类
class My3DConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride, padding):
        super(My3DConvBlock, self).__init__()
        
        # 3D 卷积层
        self.conv = nn.Conv3d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding)
        
        # 批量归一化层
        self.bn = nn.BatchNorm3d(out_channels)
        
        # ReLU 激活函数
        self.relu = nn.ReLU(inplace=True)
        
        # 注意力机制（用于计算权重系数）
        self.attention = nn.Sequential(
            nn.Linear(out_channels, out_channels // 4),
            nn.ReLU(inplace=True),
            nn.Linear(out_channels // 4, out_channels),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        
        # 计算注意力权重系数
        attention_weight = self.attention(torch.mean(x, dim=(2,3,4)))
        attention_weight = attention_weight.unsqueeze(-1).unsqueeze(-1).unsqueeze(-1)
        
        # 乘上注意力权重系数
        x = x * attention_weight
        
        return x

class FeatureExtractor3DCNN(nn.Module):
    def __init__(self):
        super(FeatureExtractor3DCNN, self).__init__()
        
        # 3D convolution block 1
        self.conv_block1 = My3DConvBlock(1, 32, kernel_size=3, stride=1, padding=1)
        
        # 3D pooling layer
        self.pool1 = nn.MaxPool3d(kernel_size=2, stride=2)
        
        # 3D convolution block 2
        self.conv_block2 = My3DConvBlock(32, 64, kernel_size=3, stride=1, padding=1)
        
        # 3D pooling layer
        self.pool2 = nn.MaxPool3d(kernel_size=2, stride=2)
        
    def forward(self, x):
        x = self.conv_block1(x)
        x = self.pool1(x)
        x = self.conv_block2(x)
        x = self.pool2(x)
        x = x.view(x.size(0), -1)
        return x

# %% [markdown]
# # csv特征提取模型
# - 改为提取特征

# %%
class FeatureExtractorCNN(nn.Module):
    def __init__(self):
        super(FeatureExtractorCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 29 * 29, 128)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 29 * 29)
        x = F.relu(self.fc1(x))
        return x

# %%
class MultiModalClassifier(nn.Module):
    def __init__(self, num_classes=2):
        super(MultiModalClassifier, self).__init__()
        self.feature_extractor_3d = FeatureExtractor3DCNN()
        self.feature_extractor_gray = FeatureExtractorCNN()

        # Fully connected layer to combine the features from both extractors and perform classification
        self.classifier = nn.Sequential(
            nn.Linear(128 + 64 * 15 * 18 * 15, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, num_classes)
        )

    def forward(self, x_3d, x_gray):
        features_3d = self.feature_extractor_3d(x_3d)
        features_gray = self.feature_extractor_gray(x_gray)

        # Concatenate the features from both extractors
        combined_features = torch.cat((features_3d, features_gray), dim=1)

        # Pass the combined features through the classifier
        output = self.classifier(combined_features)
        return output

# %% [markdown]
# # 训练

# %%
root_dir_3d = '/content/alff_split_1'
csvsplit_dir = os.path.join('/content/csv_split_1')  
csvtrain_dir = os.path.join(csvsplit_dir, "train")
csvvalid_dir = os.path.join(csvsplit_dir, "valid")
csvtest_dir  = os.path.join(csvsplit_dir, "test") 
niisplit_dir = os.path.join('/content/alff_split_1')  
niitrain_dir = os.path.join(niisplit_dir, "train")
niivalid_dir = os.path.join(niisplit_dir, "valid")
niitest_dir  = os.path.join(niisplit_dir, "test")

# %%
# 定义超参数
input_size = [116,116]
batch_size = 128
learning_rate = 0.001
num_epochs = 100
num_classes = 2
log_interval = 8
val_interval = 8

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MultiModalClassifier()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)     # 设置学习率下降策略

# 实例化数据集和数据加载器

train_dataset = MultiModalDataset(niitrain_dir,csvtrain_dir, transform=None)
valid_dataset = MultiModalDataset(niivalid_dir, csvvalid_dir, transform=None)
test_dataset = MultiModalDataset(niitest_dir, csvtest_dir, transform=None)
#CNN 图像模型dataloader
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,collate_fn = collate_fn,num_workers = num_workers)
# valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,collate_fn = collate_fn,num_workers = num_workers)
#非CNN 
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

print('训练')
train_losses = []
train_accs = []
valid_losses = []
valid_accs = []
# ============================ step 5/5 训练 ============================
# 训练和验证
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (images_3d, images_gray, label) in enumerate(train_loader):
        images_3d, images_gray, labels = images_3d.to(device), images_gray.to(device), label.to(device)
        optimizer.zero_grad()
        outputs = model(images_3d, images_gray)
        loss = criterion(outputs, label)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images_gray.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    train_loss = running_loss / len(train_dataset)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 验证阶段
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        total = 0
        correct = 0
        for images_3d, images_gray, label in valid_loader:
            images_3d, images_gray, labels = images_3d.to(device), images_gray.to(device), label.to(device)
            outputs = model(images_3d, images_gray)
            loss = criterion(outputs, label)
            running_loss += loss.item() * images_gray.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
            # pred = outputs.argmax(dim=1)
            # print(f"Sample: predicted={pred.item()}, target={label.item()},matched?={label.item() == pred.item()}")

    valid_loss = running_loss / len(valid_dataset)
    valid_acc = correct / total
    valid_losses.append(valid_loss)
    valid_accs.append(valid_acc)

    # 打印训练过程中的指标
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")


# 绘制训练和验证指标的图表
fig, axs = plt.subplots(2, 1, figsize=(10, 12))
axs[0].plot(train_accs, label='Train Accuracy')
axs[0].plot(valid_accs, label='Validation Accuracy')
axs[0].legend()
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Value')
axs[0].set_title('Training and Validation Metrics')

axs[1].plot(train_losses, label='Train Loss')
axs[1].plot(valid_losses, label='Validation Loss')
axs[1].legend()
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Value')
axs[1].set_title('Training and Validation Metrics')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       7 log_interval = 8
#       8 val_interval = 8
# ---> 10 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      11 model = MultiModalClassifier()
#      12 model = model.to(device)
#
# NameError: name 'torch' is not defined
